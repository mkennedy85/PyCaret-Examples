# %% [markdown]
# # 👋 PyCaret Regression Tutorial
#
# PyCaret is an open-source, low-code machine learning library in Python that automates machine learning workflows. It is an end-to-end machine learning and model management tool that exponentially speeds up the experiment cycle and makes you more productive.
#
# Compared with the other open-source machine learning libraries, PyCaret is an alternate low-code library that can be used to replace hundreds of lines of code with a few lines only. This makes experiments exponentially fast and efficient.
#
# **Course:** CMPE-255 Data Mining
# **Institution:** San José State University
# **Last Updated:** October 2025
#
# ---
#
# ## Requirements
# - Python 3.11 (recommended) or 3.10
# - PyCaret 3.3.2
# - See README.md for complete setup instructions

# %% [markdown]
# ## Environment Verification
#
# Let's verify we have the correct Python version and PyCaret installed.

# %%
# Check Python version
import sys
print(f"Python version: {sys.version}")
print(f"Version: {sys.version_info.major}.{sys.version_info.minor}.{sys.version_info.micro}")

if sys.version_info.major == 3 and 9 <= sys.version_info.minor <= 11:
    print(f"\n✅ Python {sys.version_info.major}.{sys.version_info.minor} is compatible with PyCaret!")
elif sys.version_info >= (3, 12):
    print(f"\n❌ Python 3.12+ is not supported by PyCaret 3.3.2")
    print("Please use Python 3.11 or 3.10 (see README.md for instructions)")
else:
    print(f"\n⚠️  Python {sys.version_info.major}.{sys.version_info.minor} may have compatibility issues")
# Out:
# Python version: 3.11.11 (main, Feb 12 2025, 15:06:01) [Clang 19.1.6 ]
# Version: 3.11.11
#
# ✅ Python 3.11 is compatible with PyCaret!

# %%
# Verify PyCaret installation
try:
    import pycaret
    print(f"PyCaret version: {pycaret.__version__}")
    
    import numpy as np
    import pandas as pd
    import sklearn
    
    print(f"NumPy version: {np.__version__}")
    print(f"Pandas version: {pd.__version__}")
    print(f"Scikit-learn version: {sklearn.__version__}")
    
    print("\n✅ All packages installed successfully!")
    print("Ready to start the tutorial.")
    
except ImportError as e:
    print(f"\n❌ Import error: {e}")
    print("\nPlease install PyCaret:")
    print("  pip install pycaret[full]==3.3.2")
    print("\nSee README.md for complete setup instructions.")
# Out:
# PyCaret version: 3.3.2
# NumPy version: 1.26.4
# Pandas version: 2.1.4
# Scikit-learn version: 1.4.2
#
# ✅ All packages installed successfully!
# Ready to start the tutorial.

# %% [markdown]
# ---
#
# # 🚀 Quick Start Tutorial
#
# PyCaret's Regression Module is a supervised machine learning module used for estimating relationships between a dependent variable (target) and one or more independent variables (features).
#
# **Objective:** Predict continuous values such as:
# - Sales amounts
# - Quantities
# - Temperatures
# - Insurance charges (our example)
#
# ## Typical PyCaret Workflow
#
# **Setup** ➡️ **Compare Models** ➡️ **Analyze Model** ➡️ **Prediction** ➡️ **Save Model**

# %% [markdown]
# ## Step 1: Load Data
#
# We'll use the insurance dataset from PyCaret's built-in datasets.

# %%
import os
from pathlib import Path
import pandas as pd

# Setup data directory
data_dir = Path('../datasets/regression')
data_dir.mkdir(parents=True, exist_ok=True)

data_path = data_dir / 'housing.csv'

# Download from Kaggle if not already present
if not data_path.exists():
    print(f"📥 Downloading dataset from Kaggle...")

    # Check for Kaggle credentials
    kaggle_json = Path.home() / '.kaggle' / 'kaggle.json'

    if not kaggle_json.exists():
        print("⚠️  Kaggle credentials not found!")
        print("\nTo download datasets automatically, you need Kaggle API credentials:")
        print("1. Go to https://www.kaggle.com/settings")
        print("2. Scroll to 'API' section and click 'Create New API Token'")
        print("3. This downloads kaggle.json")
        print("4. Upload kaggle.json to your home directory:")
        print("   - In Vertex AI: Upload to /home/jupyter/.kaggle/")
        print("   - Or set KAGGLE_USERNAME and KAGGLE_KEY environment variables")
        print("\nFor now, using a backup URL...")

        # Fallback: Try to download from a direct URL if available
        try:
            import urllib.request
            # Note: This URL is a placeholder - update with actual backup URL if available
            backup_url = "https://storage.googleapis.com/pycaret-examples-backup/regression/housing.csv"
            print(f"Trying backup URL: {backup_url}")
            urllib.request.urlretrieve(backup_url, data_path)
            print("✅ Downloaded from backup URL")
        except Exception as e:
            print(f"❌ Backup download failed: {e}")
            raise Exception("Please upload kaggle.json or manually download the dataset")
    else:
        # Download using Kaggle API
        import kaggle
        print(f"Downloading from Kaggle: camnugent/california-housing-prices")
        kaggle.api.dataset_download_files(
            'camnugent/california-housing-prices',
            path=data_dir,
            unzip=True,
            quiet=False
        )
        print(f"✅ Dataset downloaded to {data_dir}")
else:
    print(f"✅ Dataset already exists at {data_path}")

# Load the data
print(f"\n📊 Loading dataset...")
data = pd.read_csv(data_path)
print(f"Dataset shape: {data.shape}")
# Out:
# Dataset shape: (20640, 10)
#
# Columns: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'ocean_proximity']
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Quick data exploration
print("Dataset Info:")
data.info()

print("\n" + "="*50)
print("Statistical Summary:")
data.describe()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
#
# ==================================================
# Statistical Summary:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# ## Step 2: Setup
#
# The `setup()` function initializes the training environment and creates the transformation pipeline.
#
# **This is the most important step in PyCaret!**
#
# ### Required Parameters:
# - `data`: Your pandas DataFrame
# - `target`: Name of the target column
#
# ### Common Optional Parameters:
# - `session_id`: Random seed for reproducibility
# - `train_size`: Proportion of data for training (default: 0.7)
# - `normalize`: Enable feature normalization
# - `transformation`: Enable feature transformation
# - `pca`: Enable PCA for dimensionality reduction
# - `verbose`: Control output verbosity

# %%
from pycaret.regression import *

# Initialize the setup
s = setup(data, target='median_house_value', fold=3, session_id=123)  # fold=3 for faster execution
# Out:
# <style type="text/css">
# #T_a132d_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a132d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a132d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a132d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a132d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a132d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a132d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a132d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a132d_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a132d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a132d_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a132d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a132d_row3_col1" class="data row3 col1" >(20640, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a132d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a132d_row4_col1" class="data row4 col1" >(20640, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a132d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a132d_row5_col1" class="data row5 col1" >(14447, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a132d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a132d_row6_col1" class="data row6 col1" >(6193, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a132d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a132d_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a132d_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_a132d_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a132d_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_a132d_row9_col1" class="data row9 col1" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a132d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_a132d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a132d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_a132d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a132d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_a132d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a132d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_a132d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a132d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_a132d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a132d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_a132d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a132d_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_a132d_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a132d_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_a132d_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a132d_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_a132d_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a132d_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_a132d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a132d_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_a132d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a132d_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_a132d_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a132d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a132d_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_a132d_row22_col1" class="data row22 col1" >f4ba</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Alternative: Object-Oriented API
#
# PyCaret supports both Functional and OOP approaches. Both produce identical results.

# %%
# Object-Oriented API (optional - you can skip this cell)
from pycaret.regression import RegressionExperiment

exp = RegressionExperiment()
# exp.setup(data, target='median_house_value', session_id=123)

# %% [markdown]
# ## Step 3: Compare Models
#
# The `compare_models()` function trains and evaluates ALL available estimators using cross-validation.
#
# **This is PyCaret's AutoML feature!**
#
# It will automatically:
# - Train 25+ regression models
# - Perform cross-validation
# - Evaluate on multiple metrics
# - Return the best model

# %%
# Compare top models only (fast mode)
# Testing fewer models for faster execution
best = compare_models(include=['lr', 'ridge', 'rf', 'lightgbm', 'gbr'], n_select=1)

print(f"\nBest model: {type(best).__name__}")
# Out:
# <style type="text/css">
# #T_87767 th {
#   text-align: left;
# }
# #T_87767_row0_col0, #T_87767_row1_col0, #T_87767_row1_col1, #T_87767_row1_col2, #T_87767_row1_col3, #T_87767_row1_col4, #T_87767_row1_col5, #T_87767_row1_col6, #T_87767_row2_col0, #T_87767_row2_col1, #T_87767_row2_col2, #T_87767_row2_col3, #T_87767_row2_col4, #T_87767_row2_col5, #T_87767_row2_col6, #T_87767_row3_col0, #T_87767_row3_col1, #T_87767_row3_col2, #T_87767_row3_col3, #T_87767_row3_col4, #T_87767_row3_col5, #T_87767_row3_col6, #T_87767_row4_col0, #T_87767_row4_col1, #T_87767_row4_col2, #T_87767_row4_col3, #T_87767_row4_col4, #T_87767_row4_col5, #T_87767_row4_col6, #T_87767_row5_col0, #T_87767_row5_col1, #T_87767_row5_col2, #T_87767_row5_col3, #T_87767_row5_col4, #T_87767_row5_col5, #T_87767_row5_col6, #T_87767_row6_col0, #T_87767_row6_col1, #T_87767_row6_col2, #T_87767_row6_col3, #T_87767_row6_col4, #T_87767_row6_col5, #T_87767_row6_col6, #T_87767_row7_col0, #T_87767_row7_col1, #T_87767_row7_col2, #T_87767_row7_col3, #T_87767_row7_col4, #T_87767_row7_col5, #T_87767_row7_col6, #T_87767_row8_col0, #T_87767_row8_col1, #T_87767_row8_col2, #T_87767_row8_col3, #T_87767_row8_col4, #T_87767_row8_col5, #T_87767_row8_col6, #T_87767_row9_col0, #T_87767_row9_col1, #T_87767_row9_col2, #T_87767_row9_col3, #T_87767_row9_col4, #T_87767_row9_col5, #T_87767_row9_col6, #T_87767_row10_col0, #T_87767_row10_col1, #T_87767_row10_col2, #T_87767_row10_col3, #T_87767_row10_col4, #T_87767_row10_col5, #T_87767_row10_col6, #T_87767_row11_col0, #T_87767_row11_col1, #T_87767_row11_col2, #T_87767_row11_col3, #T_87767_row11_col4, #T_87767_row11_col5, #T_87767_row11_col6, #T_87767_row12_col0, #T_87767_row12_col1, #T_87767_row12_col2, #T_87767_row12_col3, #T_87767_row12_col4, #T_87767_row12_col5, #T_87767_row12_col6, #T_87767_row13_col0, #T_87767_row13_col1, #T_87767_row13_col2, #T_87767_row13_col3, #T_87767_row13_col4, #T_87767_row13_col5, #T_87767_row13_col6, #T_87767_row14_col0, #T_87767_row14_col1, #T_87767_row14_col2, #T_87767_row14_col3, #T_87767_row14_col4, #T_87767_row14_col5, #T_87767_row14_col6, #T_87767_row15_col0, #T_87767_row15_col1, #T_87767_row15_col2, #T_87767_row15_col3, #T_87767_row15_col4, #T_87767_row15_col5, #T_87767_row15_col6, #T_87767_row16_col0, #T_87767_row16_col1, #T_87767_row16_col2, #T_87767_row16_col3, #T_87767_row16_col4, #T_87767_row16_col5, #T_87767_row16_col6, #T_87767_row17_col0, #T_87767_row17_col1, #T_87767_row17_col2, #T_87767_row17_col3, #T_87767_row17_col4, #T_87767_row17_col5, #T_87767_row17_col6 {
#   text-align: left;
# }
# #T_87767_row0_col1, #T_87767_row0_col2, #T_87767_row0_col3, #T_87767_row0_col4, #T_87767_row0_col5, #T_87767_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_87767_row0_col7, #T_87767_row1_col7, #T_87767_row2_col7, #T_87767_row3_col7, #T_87767_row4_col7, #T_87767_row5_col7, #T_87767_row6_col7, #T_87767_row7_col7, #T_87767_row8_col7, #T_87767_row9_col7, #T_87767_row10_col7, #T_87767_row11_col7, #T_87767_row12_col7, #T_87767_row13_col7, #T_87767_row14_col7, #T_87767_row15_col7, #T_87767_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_87767_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_87767">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87767_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T
#     </tr>
#     <tr>
#       <th id="T_87767_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_87767_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_87767_row5_col1" class="data row5 col1" >50154.5348</td>
#       <td id="T_87767_row5_col2" class="data row5 col2" >4757787550.5767</td>
#       <td id="T_87767_row5_col3" class="data row5 col3" >68960.2055</td>
#       <td id="T_87767_row5_col4" class="data row5 col4" >0.6429</td>
#       <td id="T_87767_row5_col5" class="data row5 col5" >0.3811</td>
#       <td id="T_87767_row5_col6" class="data row5 col6" >0.2885</td>
#       <td id="T_87767_
# Best model: LGBMRegressor

# %%
# Access the comparison results as a DataFrame
results = pull()
results
# Out:
#                                     Model          MAE           MSE  \
# lightgbm  Light Gradient Boosting Machine   32446.5243  2.352507e+09
# rf                Random Forest Regressor   32601.1401  2.500103e+09
# et                  Extra Trees Regressor   35279.0180  2.805037e+09
# gbr           Gradient Boosting Regressor   39009.2448  3.150819e+09
# lr                      Linear Regression   50154.1376  4.757779e+09
# lasso                    Lasso Regression   50154.5348  4.757788e+09
# ridge                    Ridge Regression   50155.4032  4.757763e+09
# llar         Lasso Least Angle Regression   50154.5079  4.757786e+09
# br                         Bayesian Ridge   50167.2546  4.759929e+09
# lar                Least Angle Regression   50318.6460  4.895005e+09
# dt                Decision Tree Regressor   44638.4876  4.912372e+09
# en                            Elastic Net   52987.3000  5.140503e+09
# huber                     Huber Regressor   54495.5520  5.811439e+09
# ada                    AdaBoost Regressor   76376.0145  8.056828e+09
# knn                 K Neighbors Regressor   76416.2766  9.847365e+09
# omp           Orthogonal Matching Pursuit   90017.7920  1.310713e+10
# dummy                     Dummy Regressor   91282.2086  1.335538e+10
# par          Passive Aggressive Regressor  193020.4212  1.551678e+11
#
#                  RMSE       R2   RMSLE    MAPE  TT (Sec)
# lightgbm   48484.5478   0.8231  0.2376  0.1806     0.379
# rf         49989.2760   0.8121  0.2415  0.1817     0.622
# et         52947.4818   0.7892  0.2522  0.1955     0.220
# gbr        56118.7995   0.7633  0.2736  0.2186     0.199
# lr         68960.1376   0.6429  0.3811  0.2885     0.271
# lasso      68960.2055   0.6429  0.3811  0.2885     0.122
# ridge      68960.0498   0.6429  0.3810  0.2885     0.007
# llar       68960.1951   0.6429  0.3811  0.2885     0.007
# br         68976.0109   0.6428  0.3809  0.2887     0.006
# lar        69952.2585   0.6326  0.4105  0.2860     0.006
# dt         70063.5021   0.6310  0.3288  0.2440     0.021
# en         71685.9834   0.6143  0.3709  0.3198     0.111
# huber      76213.7983   0.5636  0.3965  0.2982     0.014
# ada        89700.8802   0.3951  0.4732  0.5194     0.063
# knn        99222.2633   0.2611  0.5155  0.4987     0.009
# omp       114451.5602   0.0179  0.5809  0.6062     0.007
# dummy     115532.1844  -0.0007  0.5886  0.6193     0.005
# par       248072.1624 -10.1058  0.6951  1.1525     0.009

# %% [markdown]
# ### Alternative: Train a Specific Model
#
# If you want to train a specific model instead of comparing all:

# %%
# View all available models
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
# SKIPPED: XGBoost has issues with column names containing special characters
# # Create a specific model (XGBoost Regressor)
# xgboost = create_model('xgboost')
#
# Note: If you want to use XGBoost, clean column names first:
# data.columns = data.columns.str.replace('[^A-Za-z0-9_]+', '', regex=True)

# %% [markdown]
# ## Step 4: Analyze Model
#
# Use `plot_model()` to visualize model performance on the test set.

# %%
# Plot residuals
plot_model(best, plot='residuals')

# %%
# Plot prediction error
plot_model(best, plot='error')

# %%
# Plot feature importance
plot_model(best, plot='feature')

# %%
# Plot learning curve
plot_model(best, plot='learning')

# %%
# Interactive evaluation (only works in Jupyter notebooks)
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Step 5: Make Predictions
#
# The `predict_model()` function generates predictions and adds them as a new column.

# %%
# Predict on the holdout (test) set
holdout_pred = predict_model(best)

print(f"Predictions shape: {holdout_pred.shape}")
holdout_pred.head(10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab47b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab47b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab47b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ab47b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ab47b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ab47b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ab47b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ab47b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab47b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab47b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ab47b_row0_col1" class="data row0 col1" >31369.6739</td>
#       <td id="T_ab47b_row0_col2" class="data row0 col2" >2131895630.1813</td>
#       <td id="T_ab47b_row0_col3" class="data row0 col3" >46172.4553</td>
#       <td id="T_ab47b_row0_col4" class="data row0 col4" >0.8388</td>
#       <td id="T_ab47b_row0_col5" class="data row0 col5" >0.2318</td>
#       <td id="T_ab47b_row0_col6" class="data row0 col6" >0.1781</td>
#     </tr>
#   </tbody>
# </table>
# Predictions shape: (6193, 11)
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19121 -122.639999  38.240002                40.0       1974.0           410.0
# 20019 -119.050003  36.090000                 9.0       3297.0           568.0
# 15104 -116.980003  32.849998                12.0       3570.0           713.0
# 3720  -118.419998  34.200001                27.0       3201.0           970.0
# 8938  -118.470001  34.009998                41.0       2704.0           557.0
# 13730 -117.180000  34.040001                41.0       1766.0           288.0
# 7955  -118.160004  33.880001                18.0       2287.0           662.0
# 15109 -116.959999  32.860001                14.0       3064.0           496.0
# 14354 -117.230003  32.750000                23.0       2415.0           653.0
# 4450  -118.209999  34.070000                42.0        902.0           318.0
#
#        population  households  median_income ocean_proximity  \
# 19121      1039.0       398.0         3.7917       <1H OCEAN
# 20019      1749.0       568.0         4.0217          INLAND
# 15104      3321.0       666.0         4.0882       <1H OCEAN
# 3720       3403.0       948.0         2.2377       <1H OCEAN
# 8938       1047.0       478.0         4.4211       <1H OCEAN
# 13730       753.0       278.0         4.9125          INLAND
# 7955       1804.0       537.0         1.9903       <1H OCEAN
# 15109      1681.0       503.0         4.4347       <1H OCEAN
# 14354      1275.0       596.0         3.1389      NEAR OCEAN
# 4450       1312.0       323.0         1.9375       <1H OCEAN
#
#        median_house_value  prediction_label
# 19121            151600.0     198882.814187
# 20019             99200.0     101132.884212
# 15104            134500.0     158276.279342
# 3720             231700.0     187507.999339
# 8938             462900.0     453448.462461
# 13730            140700.0     185615.498054
# 7955             170300.0     146602.831017
# 15109            160300.0     166447.121396
# 14354            101800.0     234407.946956
# 4450             168800.0     148379.944308

# %%
# Check prediction performance
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_true = holdout_pred['median_house_value']
y_pred = holdout_pred['prediction_label']

print("Holdout Set Performance:")
print(f"MAE: ${mean_absolute_error(y_true, y_pred):,.2f}")
print(f"RMSE: ${np.sqrt(mean_squared_error(y_true, y_pred)):,.2f}")
print(f"R² Score: {r2_score(y_true, y_pred):.4f}")
# Out:
# Holdout Set Performance:
# MAE: $31,369.67
# RMSE: $46,172.46
# R² Score: 0.8388

# %%
# Predict on new unseen data (without target column)
new_data = data.copy().drop('median_house_value', axis=1)

predictions = predict_model(best, data=new_data)

print(f"Predictions for unseen data:")
# Show first few columns and prediction
predictions[predictions.columns[:5].tolist() + ['prediction_label']].head(10)
# Out:
# Predictions for unseen data:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                41.0        880.0           129.0
# 1 -122.220001  37.860001                21.0       7099.0          1106.0
# 2 -122.239998  37.849998                52.0       1467.0           190.0
# 3 -122.250000  37.849998                52.0       1274.0           235.0
# 4 -122.250000  37.849998                52.0       1627.0           280.0
# 5 -122.250000  37.849998                52.0        919.0           213.0
# 6 -122.250000  37.840000                52.0       2535.0           489.0
# 7 -122.250000  37.840000                52.0       3104.0           687.0
# 8 -122.260002  37.840000                42.0       2555.0           665.0
# 9 -122.250000  37.840000                52.0       3549.0           707.0
#
#    prediction_label
# 0     412646.992698
# 1     421506.847007
# 2     415404.138010
# 3     344059.284174
# 4     275169.000685
# 5     260514.327118
# 6     267690.957157
# 7     255933.057195
# 8     179261.713310
# 9     282801.347753

# %% [markdown]
# ## Step 6: Save Model
#
# Save the entire pipeline (preprocessing + model) for later use.

# %%
# Save the model pipeline
save_model(best, 'insurance_model')

print("✅ Model saved as 'insurance_model.pkl'")
# Out:
# Transformation Pipeline and Model Successfully Saved
# ✅ Model saved as 'insurance_model.pkl'

# %%
# Load the model back
loaded_model = load_model('insurance_model')

print(f"✅ Model loaded: {type(loaded_model).__name__}")

# Verify it works
test_pred = predict_model(loaded_model, data=new_data.head(5))
test_pred
# Out:
# Transformation Pipeline and Model Successfully Loaded
# ✅ Model loaded: Pipeline
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                41.0        880.0           129.0
# 1 -122.220001  37.860001                21.0       7099.0          1106.0
# 2 -122.239998  37.849998                52.0       1467.0           190.0
# 3 -122.250000  37.849998                52.0       1274.0           235.0
# 4 -122.250000  37.849998                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity  prediction_label
# 0       322.0       126.0         8.3252        NEAR BAY     412646.992698
# 1      2401.0      1138.0         8.3014        NEAR BAY     421506.847007
# 2       496.0       177.0         7.2574        NEAR BAY     415404.138010
# 3       558.0       219.0         5.6431        NEAR BAY     344059.284174
# 4       565.0       259.0         3.8462        NEAR BAY     275169.000685

# %% [markdown]
# ---
#
# # 📚 Advanced Features
#
# The sections below demonstrate advanced PyCaret capabilities.

# %% [markdown]
# ## Advanced Model Comparison

# %%
# Compare only tree-based models (excluding xgboost due to column name issues)
tree_models = compare_models(
    include=['dt', 'rf', 'et', 'gbr', 'lightgbm', 'ada']
)

tree_results = pull()
tree_results
# Out:
# <style type="text/css">
# #T_0e1e9 th {
#   text-align: left;
# }
# #T_0e1e9_row0_col0, #T_0e1e9_row1_col0, #T_0e1e9_row1_col1, #T_0e1e9_row1_col2, #T_0e1e9_row1_col3, #T_0e1e9_row1_col4, #T_0e1e9_row1_col5, #T_0e1e9_row1_col6, #T_0e1e9_row2_col0, #T_0e1e9_row2_col1, #T_0e1e9_row2_col2, #T_0e1e9_row2_col3, #T_0e1e9_row2_col4, #T_0e1e9_row2_col5, #T_0e1e9_row2_col6, #T_0e1e9_row3_col0, #T_0e1e9_row3_col1, #T_0e1e9_row3_col2, #T_0e1e9_row3_col3, #T_0e1e9_row3_col4, #T_0e1e9_row3_col5, #T_0e1e9_row3_col6, #T_0e1e9_row4_col0, #T_0e1e9_row4_col1, #T_0e1e9_row4_col2, #T_0e1e9_row4_col3, #T_0e1e9_row4_col4, #T_0e1e9_row4_col5, #T_0e1e9_row4_col6, #T_0e1e9_row5_col0, #T_0e1e9_row5_col1, #T_0e1e9_row5_col2, #T_0e1e9_row5_col3, #T_0e1e9_row5_col4, #T_0e1e9_row5_col5, #T_0e1e9_row5_col6 {
#   text-align: left;
# }
# #T_0e1e9_row0_col1, #T_0e1e9_row0_col2, #T_0e1e9_row0_col3, #T_0e1e9_row0_col4, #T_0e1e9_row0_col5, #T_0e1e9_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0e1e9_row0_col7, #T_0e1e9_row1_col7, #T_0e1e9_row2_col7, #T_0e1e9_row3_col7, #T_0e1e9_row5_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0e1e9_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0e1e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e1e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0e1e9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0e1e9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0e1e9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0e1e9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0e1e9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0e1e9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0e1e9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e1e9_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0e1e9_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0e1e9_row0_col1" class="data row0 col1" >32446.5243</td>
#       <td id="T_0e1e9_row0_col2" class="data row0 col2" >2352506625.5720</td>
#       <td id="T_0e1e9_row0_col3" class="data row0 col3" >48484.5478</td>
#       <td id="T_0e1e9_row0_col4" class="data row0 col4" >0.8231</td>
#       <td id="T_0e1e9_row0_col5" class="data row0 col5" >0.2376</td>
#       <td id="T_0e1e9_row0_col6" class="data row0 col6" >0.1806</td>
#       <td id="T_0e1e9_row0_col7" class="data row0 col7" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_0e1e9_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0e1e9_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_0e1e9_row1_col1" class="data row1 col1" >32601.1401</td>
#       <td id="T_0e1e9_row1_col2" class="data row1 col2" >2500102516.8196</td>
#       <td id="T_0e1e9_row1_col3" class="data row1 col3" >49989.2760</td>
#       <td id="T_0e1e9_row1_col4" class="data row1 col4" >0.8121</td>
#       <td id="T_0e1e9_row1_col5" class="data row1 col5" >0.2415</td>
#       <td id="T_0e1e9_row1_col6" class="data row1 col6" >0.1817</td>
#       <td id="T_0e1e9_row1_col7" class="data row1 col7" >0.6850</td>
#     </tr>
#     <tr>
#       <th id="T_0e1e9_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_0e1e9_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_0e1e9_row2_col1" class="data row2 col1" >35279.0180</td>
#       <td id="T_0e1e9_row2_col2" class="data row2 col2" >2805036753.3820</td>
#       <td id="T_0e1e9_row2_col3" class="data row2 col3" >52947.4818</td>
#       <td id="T_0e1e9_row2_col4" class="data row2 col4" >0.7892</td>
#       <td id="T_0e1e9_row2_col5" class="data row2 col5" >0.2522</td>
#       <td id="T_0e1e9_row2_col6" class="data row2 col6" >0.1955</td>
#       <td id="T_0e1e9_row2_col7" class="data row2 col7" >0.2640</td>
#     </tr>
#     <tr>
#       <th id="T_0e1e9_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_0e1e9_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0e1e9_row3_col1" class="data row3 col1" >39009.2448</td>
#       <td id="T_0e1e9_row3_col2" class="data row3 col2" >3150819000.1502</td>
#       <td id="T_0e1e9_row3_col3" class="data row3 col3" >56118.7995</td>
#       <td id="T_0e1e9_row3_col4" class="data row3 col4" >0.7633</td>
#       <td id="T_0e1e9_row3_col5" class="data row3 col5" >0.2736</td>
#       <td id="T_0e1e9_row3_col6" class="data row3 col6" >0.2186</td>
#       <td id="T_0e1e9_row3_col7" class="data row3 col7" >0.2060</td>
#     </tr>
#     <tr>
#       <th id="T_0e1e9_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_0e1e9_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_0e1e9_row4_col1" class="data row4 col1" >44638.4876</td>
#       <td id="T_0e1e9_row4_col2" class="data row4 col2" >4912371571.5575</td>
#       <td id="T_0e1e9_row4_col3" class="data row4 col3" >70063.5021</td>
#       <td id="T_0e1e9_row4_col4" class="data row4 col4" >0.6310</td>
#       <td id="T_0e1e9_row4_col5" class="data row4 col5" >0.3288</td>
#       <td id="T_0e1e9_row4_col6" class="data row4 col6" >0.2440</td>
#       <td id="T_0e1e9_row4_col7" class="data row4 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_0e1e9_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_0e1e9_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_0e1e9_row5_col1" class="data row5 col1" >76376.0145</td>
#       <td id="T_0e1e9_row5_col2" class="data row5 col2" >8056828268.3613</td>
#       <td id="T_0e1e9_row5_col3" class="data row5 col3" >89700.8802</td>
#       <td id="T_0e1e9_row5_col4" class="data row5 col4" >0.3951</td>
#       <td id="T_0e1e9_row5_col5" class="data row5 col5" >0.4732</td>
#       <td id="T_0e1e9_row5_col6" class="data row5 col6" >0.5194</td>
#       <td id="T_0e1e9_row5_col7" class="data row5 col7" >0.0680</td>
#     </tr>
#   </tbody>
# </table>
#                                     Model         MAE           MSE  \
# lightgbm  Light Gradient Boosting Machine  32446.5243  2.352507e+09
# rf                Random Forest Regressor  32601.1401  2.500103e+09
# et                  Extra Trees Regressor  35279.0180  2.805037e+09
# gbr           Gradient Boosting Regressor  39009.2448  3.150819e+09
# dt                Decision Tree Regressor  44638.4876  4.912372e+09
# ada                    AdaBoost Regressor  76376.0145  8.056828e+09
#
#                 RMSE      R2   RMSLE    MAPE  TT (Sec)
# lightgbm  48484.5478  0.8231  0.2376  0.1806     0.369
# rf        49989.2760  0.8121  0.2415  0.1817     0.685
# et        52947.4818  0.7892  0.2522  0.1955     0.264
# gbr       56118.7995  0.7633  0.2736  0.2186     0.206
# dt        70063.5021  0.6310  0.3288  0.2440     0.018
# ada       89700.8802  0.3951  0.4732  0.5194     0.068

# %%
# Get top 3 models sorted by MAE
top3_mae = compare_models(sort='MAE', n_select=3)

print(f"\nTop 3 models by MAE:")
for i, model in enumerate(top3_mae, 1):
    print(f"{i}. {type(model).__name__}")
# Out:
# <style type="text/css">
# #T_5c8f6 th {
#   text-align: left;
# }
#   text-align: left;
# }
# #T_5c8f6_row0_col1, #T_5c8f6_row0_col2, #T_5c8f6_row0_col3, #T_5c8f6_row0_col4, #T_5c8f6_row0_col5, #T_5c8f6_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5c8f6_row0_col7, #T_5c8f6_row1_col7, #T_5c8f6_row2_col7, #T_5c8f6_row3_col7, #T_5c8f6_row4_col7, #T_5c8f6_row5_col7, #T_5c8f6_row6_col7, #T_5c8f6_row7_col7, #T_5c8f6_row8_col7, #T_5c8f6_row11_col7, #T_5c8f6_row12_col7, #T_5c8f6_row13_col7, #T_5c8f6_row14_col7, #T_5c8f6_row15_col7, #T_5c8f6_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5c8f6_row9_col7, #T_5c8f6_row10_col7, #T_5c8f6_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5c8f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c8f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c8f6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5c8f6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5c8f6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5c8f6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5c8f6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5c8f6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5c8f6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c8f6_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_5c8f6_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5c8f6_row0_col1" class="data row0 col1" >32446.5243</td>
#       <td id="T_5c8f6_row0_col2" class="data row0 col2" >2352506625.5720</td>
#       <td id="T_5c8f6_row0_col3" class="data row0 col3" >48484.5478</td>
#       <td id="T_5c8f6_row0_col4" class="data row0 col4" >0.8231</td>
#       <td id="T_5c8f6_row0_col5" class="data row0 col5" >0.2376</td>
#       <td id="T_5c8f6_row0_col6" class="data row0 col6" >0.1806</td>
#       <td id="T_5c8f6_row0_col7" class="data row0 col7" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_5c8f6_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_5c8f6_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_5c8f6_row1_col1" class="data row1 col1" >32601.1401</td>
#       <td id="T_5c8f6_row1_col2" class="data row1 col2" >2500102516.8196</td>
#       <td id="T_5c8f6_row1_col3" class="data row1 col3" >49989.2760</td>
#       <td id="T_5c8f6_row1_col4" class="data row1 col4" >0.8121</td>
#       <td id="T_5c8f6_row1_col5" class="data row1 col5" >0.2415</td>
#       <td id="T_5c8f6_row1_col6" class="data row1 col6" >0.1817</td>
#       <td id="T_5c8f6_row1_col7" class="data row1 col7" >0.6430</td>
#     </tr>
#     <tr>
#       <th id="T_5c8f6_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_5c8f6_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_5c8f6_row2_col1" class="data row2 col1" >35279.0180</td>
#       <td id="T_5c8f6_row2_col2" class="data row2 col2" >2805036753.3820</td>
#       <td id="T_5c8f6_row2_col3" class="data row2 col3" >52947.4818</td>
#       <td id="T_5c8f6_row2_col4" class="data row2 col4" >0.7892</td>
#       <td id="T_5c8f6_row2_col5" class="data row2 col5" >0.2522</td>
#       <td id="T_5c8f6_row2_col6" class="data row2 col6" >0.1955</td>
#       <td id="T_5c8f6_row2_col7" class="data row2 col7" >0.2350</td>
#     </tr>
#     <tr>
#       <th id="T_5c8f6_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_5c8f6_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5c8f6_row3_col1" class="data row3 col1" >39009.2448</td>
#       <td id="T_5c8f6_row3_col2" class="data row3 col2" >3150819000.1502</td>
#       <td id="T_5c8f6_row3_col3" class="data row3 col3" >56118.7995</td>
#       <td id="T_5c8f6_row3_col4" class="data row3 col4" >0.7633</td>
#       <td id="T_5c8f6_row3_col5" class="data row3 col5" >0.2736</td>
#       <td id="T_5c8f6_row3_col6" class="data row3 col6" >0.2186</td>
#       <td id="T_5c8f6_row3_col7" class="data row3 col7" >0.1950</td>
#     </tr>
#     <tr>
#       <th id="T_5c8f6_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_5c8f6_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_5c8f6_row4_col1" class="data row4 col1" >44638.4876</td>
#       <td id="T_5c8f6_row4_col2" class="data row4 col2" >4912371571.5575</td>
#       <td id="T_5c8f6_row4_col3" class="data row4 col3" >70063.5021</td>
#       <td id="T_5c8f6_row4_col4" class="data row4 col4" >0.6310</td>
#       <td id="T_5c8f6_row4_col5" class="data row4 col5" >0.3288</td>
#       <td id="T_5c8f6_row4_col6" class="data row4 col6" >0.2440</td>
#       <td id="T_5c8f6_row4_col7" class="data row4 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_5c8f6_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_5c8f6_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_5c8f6_row5_col1" class="data row5 col1" >50154.1376</td>
#       <td id="T_5c8f6_row5_col2" class="data row5 col2" >4757779475.9005</td>
#       <td id="T_5c8f6_row5_col3" class="data row5 col3" >68960.1376</td>
#       <td id="T_5c8f6_row5_col4" class="data row5 col4" >0.6429</td>
#       <td id="T_5c8f6_row5_col5" class="data row5 col5" >0.3811</td>
#       <td id="T_5c8f6_row5_col6" class="data row5 col6" >0.2885</td>
#       <td id="T_5c
# Top 3 models by MAE:
# 1. LGBMRegressor
# 2. RandomForestRegressor
# 3. ExtraTreesRegressor

# %% [markdown]
# ## Hyperparameter Tuning
#
# The `tune_model()` function performs hyperparameter optimization.

# %%
# Create a baseline decision tree
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_34023_row10_col0, #T_34023_row10_col1, #T_34023_row10_col2, #T_34023_row10_col3, #T_34023_row10_col4, #T_34023_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_34023">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34023_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_34023_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_34023_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_34023_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_34023_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_34023_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34023_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34023_row0_col0" class="data row0 col0" >42784.2062</td>
#       <td id="T_34023_row0_col1" class="data row0 col1" >4666102020.6768</td>
#       <td id="T_34023_row0_col2" class="data row0 col2" >68308.8722</td>
#       <td id="T_34023_row0_col3" class="data row0 col3" >0.6766</td>
#       <td id="T_34023_row0_col4" class="data row0 col4" >0.3237</td>
#       <td id="T_34023_row0_col5" class="data row0 col5" >0.2379</td>
#     </tr>
#     <tr>
#       <th id="T_34023_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34023_row8_col0" class="data row8 col0" >45696.0291</td>
#       <td id="T_34023_row8_col1" class="data row8 col1" >5142109910.1565</td>
#       <td id="T_34023_row8_col2" class="data row8 col2" >71708.5065</td>
#       <td id="T_34023_row8_col3" class="data row8 col3" >0.6015</td>
#       <td id="T_34023_row8_col4" class="data row8 col4" >0.3439</td>
#       <td id="T_34023_row8_col5" class="data row8 col5" >0.2532</td>
#     </tr>
#     <tr>
#       <th id="T_34023_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34023_row9_col0" class="data row9 col0" >43935.8380</td>
#       <td id="T_34023_row9_col1" class="data row9 col1" >4756227040.2008</td>
#       <td id="T_34023_row9_col2" class="data row9 col2" >68965.4047</td>
#       <td id="T_34023_row9_col3" class="data row9 col3" >0.6294</td>
#       <td id="T_34023_row9_col4" class="data row9 col4" >0.3303</td>
#       <td id="T_34023_row9_col5" class="data row9 col5" >0.2401</td>
#     </tr>
#     <tr>
#       <th id="T_34023_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_34023_row10_col0" class="data row10 col0" >44638.4876</td>
#       <td id="T_34023_row10_col1" class="data row10 col1" >4912371571.5575</td>
#       <td id="T_34023_row10_col2" class="data row10 col2" >70063.5021</td>
#       <td id="T_34023_row10_col3" class="data row10 col3" >0.6310</td>
#       <td id="T_34023_row10_col4" class="data row10 col4" >0.3288</td>
#       <td id="T_34023_row10_col5" class="data row10 col5" >0.2440</td>
#     </tr>
#     <tr>
#       <th id="T_34023_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_34023_row11_col0" class="data row11 col0" >1069.1930</td>
#       <td id="T_34023_row11_col1" class="data row11 col1" >262520651.5842</td>
#       <td id="T_34023_row11_col2" class="data row11 col2" >1864.7362</td>
#       <td id="T_34023_row11_col3" class="data row11 col3" >0.0273</td>
#       <td id="T_34023_row11_col4" class="data row11 col4" >0.0087</td>
#       <td id="T_34023_row11_col5" class="data row11 col5" >0.0098</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Tune hyperparameters using RandomizedSearchCV (default)
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_88fd3_row10_col0, #T_88fd3_row10_col1, #T_88fd3_row10_col2, #T_88fd3_row10_col3, #T_88fd3_row10_col4, #T_88fd3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_88fd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88fd3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_88fd3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_88fd3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_88fd3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_88fd3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_88fd3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88fd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88fd3_row0_col0" class="data row0 col0" >39938.2663</td>
#       <td id="T_88fd3_row0_col1" class="data row0 col1" >3566357889.8091</td>
#       <td id="T_88fd3_row0_col2" class="data row0 col2" >59718.9910</td>
#       <td id="T_88fd3_row0_col3" class="data row0 col3" >0.7528</td>
#       <td id="T_88fd3_row0_col4" class="data row0 col4" >0.2759</td>
#       <td id="T_88fd3_row0_col5" class="data row0 col5" >0.2146</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88fd3_row1_col0" class="data row1 col0" >39280.1802</td>
#       <td id="T_88fd3_row1_col1" class="data row1 col1" >3365290909.2978</td>
#       <td id="T_88fd3_row1_col2" class="data row1 col2" >58011.1275</td>
#       <td id="T_88fd3_row1_col3" class="data row1 col3" >0.7499</td>
#       <td id="T_88fd3_row1_col4" class="data row1 col4" >0.2694</td>
#       <td id="T_88fd3_row1_col5" class="data row1 col5" >0.2074</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88fd3_row2_col0" class="data row2 col0" >40228.7270</td>
#       <td id="T_88fd3_row2_col1" class="data row2 col1" >3646586374.2972</td>
#       <td id="T_88fd3_row2_col2" class="data row2 col2" >60386.9719</td>
#       <td id="T_88fd3_row2_col3" class="data row2 col3" >0.7264</td>
#       <td id="T_88fd3_row2_col4" class="data row2 col4" >0.2795</td>
#       <td id="T_88fd3_row2_col5" class="data row2 col5" >0.2168</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88fd3_row3_col0" class="data row3 col0" >41061.6146</td>
#       <td id="T_88fd3_row3_col1" class="data row3 col1" >3895020885.5675</td>
#       <td id="T_88fd3_row3_col2" class="data row3 col2" >62410.1024</td>
#       <td id="T_88fd3_row3_col3" class="data row3 col3" >0.7245</td>
#       <td id="T_88fd3_row3_col4" class="data row3 col4" >0.2868</td>
#       <td id="T_88fd3_row3_col5" class="data row3 col5" >0.2180</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_88fd3_row4_col0" class="data row4 col0" >39215.1079</td>
#       <td id="T_88fd3_row4_col1" class="data row4 col1" >3366764672.7432</td>
#       <td id="T_88fd3_row4_col2" class="data row4 col2" >58023.8285</td>
#       <td id="T_88fd3_row4_col3" class="data row4 col3" >0.7574</td>
#       <td id="T_88fd3_row4_col4" class="data row4 col4" >0.2717</td>
#       <td id="T_88fd3_row4_col5" class="data row4 col5" >0.2140</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_88fd3_row5_col0" class="data row5 col0" >40387.9398</td>
#       <td id="T_88fd3_row5_col1" class="data row5 col1" >3494946397.2423</td>
#       <td id="T_88fd3_row5_col2" class="data row5 col2" >59118.0717</td>
#       <td id="T_88fd3_row5_col3" class="data row5 col3" >0.7112</td>
#       <td id="T_88fd3_row5_col4" class="data row5 col4" >0.2874</td>
#       <td id="T_88fd3_row5_col5" class="data row5 col5" >0.2264</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_88fd3_row6_col0" class="data row6 col0" >41552.4418</td>
#       <td id="T_88fd3_row6_col1" class="data row6 col1" >3798165615.7361</td>
#       <td id="T_88fd3_row6_col2" class="data row6 col2" >61629.2594</td>
#       <td id="T_88fd3_row6_col3" class="data row6 col3" >0.7112</td>
#       <td id="T_88fd3_row6_col4" class="data row6 col4" >0.3031</td>
#       <td id="T_88fd3_row6_col5" class="data row6 col5" >0.2426</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_88fd3_row7_col0" class="data row7 col0" >42657.9266</td>
#       <td id="T_88fd3_row7_col1" class="data row7 col1" >4065463684.1014</td>
#       <td id="T_88fd3_row7_col2" class="data row7 col2" >63760.9887</td>
#       <td id="T_88fd3_row7_col3" class="data row7 col3" >0.6929</td>
#       <td id="T_88fd3_row7_col4" class="data row7 col4" >0.3033</td>
#       <td id="T_88fd3_row7_col5" class="data row7 col5" >0.2396</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_88fd3_row8_col0" class="data row8 col0" >42055.0507</td>
#       <td id="T_88fd3_row8_col1" class="data row8 col1" >4020934561.3219</td>
#       <td id="T_88fd3_row8_col2" class="data row8 col2" >63410.8395</td>
#       <td id="T_88fd3_row8_col3" class="data row8 col3" >0.6884</td>
#       <td id="T_88fd3_row8_col4" class="data row8 col4" >0.3015</td>
#       <td id="T_88fd3_row8_col5" class="data row8 col5" >0.2346</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_88fd3_row9_col0" class="data row9 col0" >40193.7409</td>
#       <td id="T_88fd3_row9_col1" class="data row9 col1" >3686463423.9908</td>
#       <td id="T_88fd3_row9_col2" class="data row9 col2" >60716.2534</td>
#       <td id="T_88fd3_row9_col3" class="data row9 col3" >0.7128</td>
#       <td id="T_88fd3_row9_col4" class="data row9 col4" >0.2878</td>
#       <td id="T_88fd3_row9_col5" class="data row9 col5" >0.2203</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_88fd3_row10_col0" class="data row10 col0" >40657.0996</td>
#       <td id="T_88fd3_row10_col1" class="data row10 col1" >3690599441.4107</td>
#       <td id="T_88fd3_row10_col2" class="data row10 col2" >60718.6434</td>
#       <td id="T_88fd3_row10_col3" class="data row10 col3" >0.7228</td>
#       <td id="T_88fd3_row10_col4" class="data row10 col4" >0.2867</td>
#       <td id="T_88fd3_row10_col5" class="data row10 col5" >0.2234</td>
#     </tr>
#     <tr>
#       <th id="T_88fd3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_88fd3_row11_col0" class="data row11 col0" >1090.2048</td>
#       <td id="T_88fd3_row11_col1" class="data row11 col1" >238614340.0137</td>
#       <td id="T_88fd3_row11_col2" class="data row11 col2" >1961.0675</td>
#       <td id="T_88fd3_row11_col3" class="data row11 col3" >0.0230</td>
#       <td id="T_88fd3_row11_col4" class="data row11 col4" >0.0121</td>
#       <td id="T_88fd3_row11_col5" class="data row11 col5" >0.0113</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Tune with custom grid
dt_grid = {
    'max_depth': [2, 4, 6, 8, 10, 12],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

tuned_dt_custom = tune_model(dt, custom_grid=dt_grid, optimize='MAE')
# Out:
# <style type="text/css">
# #T_b7854_row10_col0, #T_b7854_row10_col1, #T_b7854_row10_col2, #T_b7854_row10_col3, #T_b7854_row10_col4, #T_b7854_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b7854">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7854_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b7854_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b7854_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b7854_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b7854_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b7854_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7854_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7854_row0_col0" class="data row0 col0" >40156.5466</td>
#       <td id="T_b7854_row0_col1" class="data row0 col1" >3572827359.7275</td>
#       <td id="T_b7854_row0_col2" class="data row0 col2" >59773.1324</td>
#       <td id="T_b7854_row0_col3" class="data row0 col3" >0.7524</td>
#       <td id="T_b7854_row0_col4" class="data row0 col4" >0.2790</td>
#       <td id="T_b7854_row0_col5" class="data row0 col5" >0.2169</td>
#     </tr>
#     <tr>
#       <th id="T_b7854_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7854_row8_col0" class="data row8 col0" >41495.5995</td>
#       <td id="T_b7854_row8_col1" class="data row8 col1" >3823246597.4795</td>
#       <td id="T_b7854_row8_col2" class="data row8 col2" >61832.4073</td>
#       <td id="T_b7854_row8_col3" class="data row8 col3" >0.7037</td>
#       <td id="T_b7854_row8_col4" class="data row8 col4" >0.2962</td>
#       <td id="T_b7854_row8_col5" class="data row8 col5" >0.2301</td>
#     </tr>
#     <tr>
#       <th id="T_b7854_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b7854_row9_col0" class="data row9 col0" >40868.7718</td>
#       <td id="T_b7854_row9_col1" class="data row9 col1" >3789709791.5620</td>
#       <td id="T_b7854_row9_col2" class="data row9 col2" >61560.6188</td>
#       <td id="T_b7854_row9_col3" class="data row9 col3" >0.7047</td>
#       <td id="T_b7854_row9_col4" class="data row9 col4" >0.2887</td>
#       <td id="T_b7854_row9_col5" class="data row9 col5" >0.2221</td>
#     </tr>
#     <tr>
#       <th id="T_b7854_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b7854_row10_col0" class="data row10 col0" >40680.4468</td>
#       <td id="T_b7854_row10_col1" class="data row10 col1" >3664705310.5196</td>
#       <td id="T_b7854_row10_col2" class="data row10 col2" >60518.9350</td>
#       <td id="T_b7854_row10_col3" class="data row10 col3" >0.7246</td>
#       <td id="T_b7854_row10_col4" class="data row10 col4" >0.2863</td>
#       <td id="T_b7854_row10_col5" class="data row10 col5" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_b7854_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b7854_row11_col0" class="data row11 col0" >852.0549</td>
#       <td id="T_b7854_row11_col1" class="data row11 col1" >176891664.0740</td>
#       <td id="T_b7854_row11_col2" class="data row11 col2" >1470.9935</td>
#       <td id="T_b7854_row11_col3" class="data row11 col3" >0.0213</td>
#       <td id="T_b7854_row11_col4" class="data row11 col4" >0.0088</td>
#       <td id="T_b7854_row11_col5" class="data row11 col5" >0.0089</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# SKIPPED: Requires optuna-integration package
# # Tune using Optuna (Bayesian optimization)
# # Note: This requires optuna to be installed
# # pip install optuna
# 
# tuned_dt_optuna = tune_model(dt, search_library='optuna', n_iter=20)

# %% [markdown]
# ## Ensemble Methods

# %%
# Bagging ensemble
bagged_dt = ensemble_model(dt, method='Bagging')
# Out:
# <style type="text/css">
# #T_f945a_row10_col0, #T_f945a_row10_col1, #T_f945a_row10_col2, #T_f945a_row10_col3, #T_f945a_row10_col4, #T_f945a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f945a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f945a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f945a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f945a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f945a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f945a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f945a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f945a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f945a_row0_col0" class="data row0 col0" >33859.7570</td>
#       <td id="T_f945a_row0_col1" class="data row0 col1" >2699342950.0456</td>
#       <td id="T_f945a_row0_col2" class="data row0 col2" >51955.2014</td>
#       <td id="T_f945a_row0_col3" class="data row0 col3" >0.8129</td>
#       <td id="T_f945a_row0_col4" class="data row0 col4" >0.2467</td>
#       <td id="T_f945a_row0_col5" class="data row0 col5" >0.1868</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f945a_row1_col0" class="data row1 col0" >34174.3316</td>
#       <td id="T_f945a_row1_col1" class="data row1 col1" >2639802390.1940</td>
#       <td id="T_f945a_row1_col2" class="data row1 col2" >51379.0073</td>
#       <td id="T_f945a_row1_col3" class="data row1 col3" >0.8039</td>
#       <td id="T_f945a_row1_col4" class="data row1 col4" >0.2400</td>
#       <td id="T_f945a_row1_col5" class="data row1 col5" >0.1799</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f945a_row2_col0" class="data row2 col0" >34138.2145</td>
#       <td id="T_f945a_row2_col1" class="data row2 col1" >2699098212.9601</td>
#       <td id="T_f945a_row2_col2" class="data row2 col2" >51952.8461</td>
#       <td id="T_f945a_row2_col3" class="data row2 col3" >0.7975</td>
#       <td id="T_f945a_row2_col4" class="data row2 col4" >0.2493</td>
#       <td id="T_f945a_row2_col5" class="data row2 col5" >0.1864</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f945a_row3_col0" class="data row3 col0" >34426.6419</td>
#       <td id="T_f945a_row3_col1" class="data row3 col1" >2803254321.1142</td>
#       <td id="T_f945a_row3_col2" class="data row3 col2" >52945.7677</td>
#       <td id="T_f945a_row3_col3" class="data row3 col3" >0.8017</td>
#       <td id="T_f945a_row3_col4" class="data row3 col4" >0.2483</td>
#       <td id="T_f945a_row3_col5" class="data row3 col5" >0.1856</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f945a_row4_col0" class="data row4 col0" >33076.1878</td>
#       <td id="T_f945a_row4_col1" class="data row4 col1" >2538613746.7188</td>
#       <td id="T_f945a_row4_col2" class="data row4 col2" >50384.6579</td>
#       <td id="T_f945a_row4_col3" class="data row4 col3" >0.8171</td>
#       <td id="T_f945a_row4_col4" class="data row4 col4" >0.2420</td>
#       <td id="T_f945a_row4_col5" class="data row4 col5" >0.1819</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f945a_row5_col0" class="data row5 col0" >34788.6247</td>
#       <td id="T_f945a_row5_col1" class="data row5 col1" >2657556629.7720</td>
#       <td id="T_f945a_row5_col2" class="data row5 col2" >51551.4949</td>
#       <td id="T_f945a_row5_col3" class="data row5 col3" >0.7804</td>
#       <td id="T_f945a_row5_col4" class="data row5 col4" >0.2538</td>
#       <td id="T_f945a_row5_col5" class="data row5 col5" >0.1948</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f945a_row6_col0" class="data row6 col0" >35254.0298</td>
#       <td id="T_f945a_row6_col1" class="data row6 col1" >2755386173.9315</td>
#       <td id="T_f945a_row6_col2" class="data row6 col2" >52491.7724</td>
#       <td id="T_f945a_row6_col3" class="data row6 col3" >0.7905</td>
#       <td id="T_f945a_row6_col4" class="data row6 col4" >0.2625</td>
#       <td id="T_f945a_row6_col5" class="data row6 col5" >0.2040</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f945a_row7_col0" class="data row7 col0" >34553.5217</td>
#       <td id="T_f945a_row7_col1" class="data row7 col1" >2701610122.1353</td>
#       <td id="T_f945a_row7_col2" class="data row7 col2" >51977.0153</td>
#       <td id="T_f945a_row7_col3" class="data row7 col3" >0.7959</td>
#       <td id="T_f945a_row7_col4" class="data row7 col4" >0.2579</td>
#       <td id="T_f945a_row7_col5" class="data row7 col5" >0.1969</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f945a_row8_col0" class="data row8 col0" >35652.1228</td>
#       <td id="T_f945a_row8_col1" class="data row8 col1" >2934693110.0843</td>
#       <td id="T_f945a_row8_col2" class="data row8 col2" >54172.8078</td>
#       <td id="T_f945a_row8_col3" class="data row8 col3" >0.7726</td>
#       <td id="T_f945a_row8_col4" class="data row8 col4" >0.2623</td>
#       <td id="T_f945a_row8_col5" class="data row8 col5" >0.1995</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f945a_row9_col0" class="data row9 col0" >33686.4564</td>
#       <td id="T_f945a_row9_col1" class="data row9 col1" >2722968832.6215</td>
#       <td id="T_f945a_row9_col2" class="data row9 col2" >52182.0739</td>
#       <td id="T_f945a_row9_col3" class="data row9 col3" >0.7878</td>
#       <td id="T_f945a_row9_col4" class="data row9 col4" >0.2495</td>
#       <td id="T_f945a_row9_col5" class="data row9 col5" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f945a_row10_col0" class="data row10 col0" >34360.9888</td>
#       <td id="T_f945a_row10_col1" class="data row10 col1" >2715232648.9577</td>
#       <td id="T_f945a_row10_col2" class="data row10 col2" >52099.2645</td>
#       <td id="T_f945a_row10_col3" class="data row10 col3" >0.7960</td>
#       <td id="T_f945a_row10_col4" class="data row10 col4" >0.2512</td>
#       <td id="T_f945a_row10_col5" class="data row10 col5" >0.1903</td>
#     </tr>
#     <tr>
#       <th id="T_f945a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f945a_row11_col0" class="data row11 col0" >716.2549</td>
#       <td id="T_f945a_row11_col1" class="data row11 col1" >99242995.9345</td>
#       <td id="T_f945a_row11_col2" class="data row11 col2" >948.3093</td>
#       <td id="T_f945a_row11_col3" class="data row11 col3" >0.0131</td>
#       <td id="T_f945a_row11_col4" class="data row11 col4" >0.0074</td>
#       <td id="T_f945a_row11_col5" class="data row11 col5" >0.0076</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Boosting ensemble (AdaBoost)
boosted_dt = ensemble_model(dt, method='Boosting')
# Out:
# <style type="text/css">
# #T_4f696_row10_col0, #T_4f696_row10_col1, #T_4f696_row10_col2, #T_4f696_row10_col3, #T_4f696_row10_col4, #T_4f696_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4f696">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f696_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4f696_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4f696_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4f696_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4f696_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4f696_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f696_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f696_row0_col0" class="data row0 col0" >32151.2457</td>
#       <td id="T_4f696_row0_col1" class="data row0 col1" >2624064080.0346</td>
#       <td id="T_4f696_row0_col2" class="data row0 col2" >51225.6194</td>
#       <td id="T_4f696_row0_col3" class="data row0 col3" >0.8181</td>
#       <td id="T_4f696_row0_col4" class="data row0 col4" >0.2376</td>
#       <td id="T_4f696_row0_col5" class="data row0 col5" >0.1713</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f696_row1_col0" class="data row1 col0" >33272.1343</td>
#       <td id="T_4f696_row1_col1" class="data row1 col1" >2777051128.4664</td>
#       <td id="T_4f696_row1_col2" class="data row1 col2" >52697.7336</td>
#       <td id="T_4f696_row1_col3" class="data row1 col3" >0.7937</td>
#       <td id="T_4f696_row1_col4" class="data row1 col4" >0.2431</td>
#       <td id="T_4f696_row1_col5" class="data row1 col5" >0.1714</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f696_row2_col0" class="data row2 col0" >33961.0657</td>
#       <td id="T_4f696_row2_col1" class="data row2 col1" >2943604447.7785</td>
#       <td id="T_4f696_row2_col2" class="data row2 col2" >54254.9947</td>
#       <td id="T_4f696_row2_col3" class="data row2 col3" >0.7791</td>
#       <td id="T_4f696_row2_col4" class="data row2 col4" >0.2493</td>
#       <td id="T_4f696_row2_col5" class="data row2 col5" >0.1757</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f696_row3_col0" class="data row3 col0" >34038.0969</td>
#       <td id="T_4f696_row3_col1" class="data row3 col1" >2999270203.2180</td>
#       <td id="T_4f696_row3_col2" class="data row3 col2" >54765.5932</td>
#       <td id="T_4f696_row3_col3" class="data row3 col3" >0.7879</td>
#       <td id="T_4f696_row3_col4" class="data row3 col4" >0.2477</td>
#       <td id="T_4f696_row3_col5" class="data row3 col5" >0.1732</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f696_row4_col0" class="data row4 col0" >32454.2920</td>
#       <td id="T_4f696_row4_col1" class="data row4 col1" >2646303246.8180</td>
#       <td id="T_4f696_row4_col2" class="data row4 col2" >51442.2321</td>
#       <td id="T_4f696_row4_col3" class="data row4 col3" >0.8093</td>
#       <td id="T_4f696_row4_col4" class="data row4 col4" >0.2430</td>
#       <td id="T_4f696_row4_col5" class="data row4 col5" >0.1766</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f696_row5_col0" class="data row5 col0" >34342.0969</td>
#       <td id="T_4f696_row5_col1" class="data row5 col1" >2910322901.1972</td>
#       <td id="T_4f696_row5_col2" class="data row5 col2" >53947.4087</td>
#       <td id="T_4f696_row5_col3" class="data row5 col3" >0.7595</td>
#       <td id="T_4f696_row5_col4" class="data row5 col4" >0.2606</td>
#       <td id="T_4f696_row5_col5" class="data row5 col5" >0.1853</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f696_row6_col0" class="data row6 col0" >34138.6491</td>
#       <td id="T_4f696_row6_col1" class="data row6 col1" >2897695879.4796</td>
#       <td id="T_4f696_row6_col2" class="data row6 col2" >53830.2506</td>
#       <td id="T_4f696_row6_col3" class="data row6 col3" >0.7797</td>
#       <td id="T_4f696_row6_col4" class="data row6 col4" >0.2633</td>
#       <td id="T_4f696_row6_col5" class="data row6 col5" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f696_row7_col0" class="data row7 col0" >35084.9294</td>
#       <td id="T_4f696_row7_col1" class="data row7 col1" >2988677773.8490</td>
#       <td id="T_4f696_row7_col2" class="data row7 col2" >54668.8007</td>
#       <td id="T_4f696_row7_col3" class="data row7 col3" >0.7743</td>
#       <td id="T_4f696_row7_col4" class="data row7 col4" >0.2693</td>
#       <td id="T_4f696_row7_col5" class="data row7 col5" >0.1953</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f696_row8_col0" class="data row8 col0" >33891.2403</td>
#       <td id="T_4f696_row8_col1" class="data row8 col1" >3052845720.6724</td>
#       <td id="T_4f696_row8_col2" class="data row8 col2" >55252.5630</td>
#       <td id="T_4f696_row8_col3" class="data row8 col3" >0.7634</td>
#       <td id="T_4f696_row8_col4" class="data row8 col4" >0.2595</td>
#       <td id="T_4f696_row8_col5" class="data row8 col5" >0.1805</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f696_row9_col0" class="data row9 col0" >35145.8747</td>
#       <td id="T_4f696_row9_col1" class="data row9 col1" >3021698133.5478</td>
#       <td id="T_4f696_row9_col2" class="data row9 col2" >54969.9748</td>
#       <td id="T_4f696_row9_col3" class="data row9 col3" >0.7646</td>
#       <td id="T_4f696_row9_col4" class="data row9 col4" >0.2647</td>
#       <td id="T_4f696_row9_col5" class="data row9 col5" >0.1914</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4f696_row10_col0" class="data row10 col0" >33847.9625</td>
#       <td id="T_4f696_row10_col1" class="data row10 col1" >2886153351.5062</td>
#       <td id="T_4f696_row10_col2" class="data row10 col2" >53705.5171</td>
#       <td id="T_4f696_row10_col3" class="data row10 col3" >0.7830</td>
#       <td id="T_4f696_row10_col4" class="data row10 col4" >0.2538</td>
#       <td id="T_4f696_row10_col5" class="data row10 col5" >0.1814</td>
#     </tr>
#     <tr>
#       <th id="T_4f696_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4f696_row11_col0" class="data row11 col0" >935.2481</td>
#       <td id="T_4f696_row11_col1" class="data row11 col1" >145466694.7290</td>
#       <td id="T_4f696_row11_col2" class="data row11 col2" >1367.7666</td>
#       <td id="T_4f696_row11_col3" class="data row11 col3" >0.0185</td>
#       <td id="T_4f696_row11_col4" class="data row11 col4" >0.0104</td>
#       <td id="T_4f696_row11_col5" class="data row11 col5" >0.0088</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Blend & Stack Models

# %%
# Blend multiple models (voting regressor)
blended = blend_models(top3_mae)
# Out:
# <style type="text/css">
# #T_03307_row10_col0, #T_03307_row10_col1, #T_03307_row10_col2, #T_03307_row10_col3, #T_03307_row10_col4, #T_03307_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_03307">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03307_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_03307_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_03307_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_03307_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_03307_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_03307_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03307_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03307_row0_col0" class="data row0 col0" >31541.3143</td>
#       <td id="T_03307_row0_col1" class="data row0 col1" >2222730148.4782</td>
#       <td id="T_03307_row0_col2" class="data row0 col2" >47145.8391</td>
#       <td id="T_03307_row0_col3" class="data row0 col3" >0.8459</td>
#       <td id="T_03307_row0_col4" class="data row0 col4" >0.2267</td>
#       <td id="T_03307_row0_col5" class="data row0 col5" >0.1753</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03307_row1_col0" class="data row1 col0" >31954.1980</td>
#       <td id="T_03307_row1_col1" class="data row1 col1" >2230378189.5190</td>
#       <td id="T_03307_row1_col2" class="data row1 col2" >47226.8799</td>
#       <td id="T_03307_row1_col3" class="data row1 col3" >0.8343</td>
#       <td id="T_03307_row1_col4" class="data row1 col4" >0.2196</td>
#       <td id="T_03307_row1_col5" class="data row1 col5" >0.1685</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03307_row2_col0" class="data row2 col0" >32477.7665</td>
#       <td id="T_03307_row2_col1" class="data row2 col1" >2433110212.3953</td>
#       <td id="T_03307_row2_col2" class="data row2 col2" >49326.5670</td>
#       <td id="T_03307_row2_col3" class="data row2 col3" >0.8174</td>
#       <td id="T_03307_row2_col4" class="data row2 col4" >0.2354</td>
#       <td id="T_03307_row2_col5" class="data row2 col5" >0.1777</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03307_row3_col0" class="data row3 col0" >32475.5731</td>
#       <td id="T_03307_row3_col1" class="data row3 col1" >2568426617.4926</td>
#       <td id="T_03307_row3_col2" class="data row3 col2" >50679.6470</td>
#       <td id="T_03307_row3_col3" class="data row3 col3" >0.8183</td>
#       <td id="T_03307_row3_col4" class="data row3 col4" >0.2355</td>
#       <td id="T_03307_row3_col5" class="data row3 col5" >0.1757</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03307_row4_col0" class="data row4 col0" >31407.2579</td>
#       <td id="T_03307_row4_col1" class="data row4 col1" >2251806653.7559</td>
#       <td id="T_03307_row4_col2" class="data row4 col2" >47453.2049</td>
#       <td id="T_03307_row4_col3" class="data row4 col3" >0.8378</td>
#       <td id="T_03307_row4_col4" class="data row4 col4" >0.2286</td>
#       <td id="T_03307_row4_col5" class="data row4 col5" >0.1739</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03307_row5_col0" class="data row5 col0" >32886.8446</td>
#       <td id="T_03307_row5_col1" class="data row5 col1" >2431345988.2006</td>
#       <td id="T_03307_row5_col2" class="data row5 col2" >49308.6807</td>
#       <td id="T_03307_row5_col3" class="data row5 col3" >0.7991</td>
#       <td id="T_03307_row5_col4" class="data row5 col4" >0.2451</td>
#       <td id="T_03307_row5_col5" class="data row5 col5" >0.1867</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03307_row6_col0" class="data row6 col0" >32749.6700</td>
#       <td id="T_03307_row6_col1" class="data row6 col1" >2410085217.1907</td>
#       <td id="T_03307_row6_col2" class="data row6 col2" >49092.6188</td>
#       <td id="T_03307_row6_col3" class="data row6 col3" >0.8167</td>
#       <td id="T_03307_row6_col4" class="data row6 col4" >0.2481</td>
#       <td id="T_03307_row6_col5" class="data row6 col5" >0.1913</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03307_row7_col0" class="data row7 col0" >32416.6880</td>
#       <td id="T_03307_row7_col1" class="data row7 col1" >2346079048.7700</td>
#       <td id="T_03307_row7_col2" class="data row7 col2" >48436.3402</td>
#       <td id="T_03307_row7_col3" class="data row7 col3" >0.8228</td>
#       <td id="T_03307_row7_col4" class="data row7 col4" >0.2450</td>
#       <td id="T_03307_row7_col5" class="data row7 col5" >0.1876</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03307_row8_col0" class="data row8 col0" >32566.6887</td>
#       <td id="T_03307_row8_col1" class="data row8 col1" >2523048718.1117</td>
#       <td id="T_03307_row8_col2" class="data row8 col2" >50229.9584</td>
#       <td id="T_03307_row8_col3" class="data row8 col3" >0.8045</td>
#       <td id="T_03307_row8_col4" class="data row8 col4" >0.2455</td>
#       <td id="T_03307_row8_col5" class="data row8 col5" >0.1839</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03307_row9_col0" class="data row9 col0" >32274.0453</td>
#       <td id="T_03307_row9_col1" class="data row9 col1" >2446966661.6230</td>
#       <td id="T_03307_row9_col2" class="data row9 col2" >49466.8238</td>
#       <td id="T_03307_row9_col3" class="data row9 col3" >0.8093</td>
#       <td id="T_03307_row9_col4" class="data row9 col4" >0.2385</td>
#       <td id="T_03307_row9_col5" class="data row9 col5" >0.1799</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_03307_row10_col0" class="data row10 col0" >32275.0046</td>
#       <td id="T_03307_row10_col1" class="data row10 col1" >2386397745.5537</td>
#       <td id="T_03307_row10_col2" class="data row10 col2" >48836.6560</td>
#       <td id="T_03307_row10_col3" class="data row10 col3" >0.8206</td>
#       <td id="T_03307_row10_col4" class="data row10 col4" >0.2368</td>
#       <td id="T_03307_row10_col5" class="data row10 col5" >0.1801</td>
#     </tr>
#     <tr>
#       <th id="T_03307_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_03307_row11_col0" class="data row11 col0" >466.9425</td>
#       <td id="T_03307_row11_col1" class="data row11 col1" >114503113.9321</td>
#       <td id="T_03307_row11_col2" class="data row11 col2" >1174.2140</td>
#       <td id="T_03307_row11_col3" class="data row11 col3" >0.0142</td>
#       <td id="T_03307_row11_col4" class="data row11 col4" >0.0090</td>
#       <td id="T_03307_row11_col5" class="data row11 col5" >0.0068</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Stack models (meta-learning)
stacked = stack_models(top3_mae)
# Out:
# <style type="text/css">
# #T_d9b0f_row10_col0, #T_d9b0f_row10_col1, #T_d9b0f_row10_col2, #T_d9b0f_row10_col3, #T_d9b0f_row10_col4, #T_d9b0f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d9b0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b0f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d9b0f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d9b0f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d9b0f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d9b0f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d9b0f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b0f_row0_col0" class="data row0 col0" >31196.6953</td>
#       <td id="T_d9b0f_row0_col1" class="data row0 col1" >2141913740.1765</td>
#       <td id="T_d9b0f_row0_col2" class="data row0 col2" >46280.8140</td>
#       <td id="T_d9b0f_row0_col3" class="data row0 col3" >0.8515</td>
#       <td id="T_d9b0f_row0_col4" class="data row0 col4" >0.2225</td>
#       <td id="T_d9b0f_row0_col5" class="data row0 col5" >0.1692</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9b0f_row1_col0" class="data row1 col0" >31439.9220</td>
#       <td id="T_d9b0f_row1_col1" class="data row1 col1" >2139822608.6575</td>
#       <td id="T_d9b0f_row1_col2" class="data row1 col2" >46258.2167</td>
#       <td id="T_d9b0f_row1_col3" class="data row1 col3" >0.8410</td>
#       <td id="T_d9b0f_row1_col4" class="data row1 col4" >0.2173</td>
#       <td id="T_d9b0f_row1_col5" class="data row1 col5" >0.1644</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9b0f_row2_col0" class="data row2 col0" >32120.2152</td>
#       <td id="T_d9b0f_row2_col1" class="data row2 col1" >2382580666.0498</td>
#       <td id="T_d9b0f_row2_col2" class="data row2 col2" >48811.6858</td>
#       <td id="T_d9b0f_row2_col3" class="data row2 col3" >0.8212</td>
#       <td id="T_d9b0f_row2_col4" class="data row2 col4" >0.2315</td>
#       <td id="T_d9b0f_row2_col5" class="data row2 col5" >0.1730</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9b0f_row3_col0" class="data row3 col0" >31551.0272</td>
#       <td id="T_d9b0f_row3_col1" class="data row3 col1" >2437847213.0371</td>
#       <td id="T_d9b0f_row3_col2" class="data row3 col2" >49374.5604</td>
#       <td id="T_d9b0f_row3_col3" class="data row3 col3" >0.8276</td>
#       <td id="T_d9b0f_row3_col4" class="data row3 col4" >0.2304</td>
#       <td id="T_d9b0f_row3_col5" class="data row3 col5" >0.1685</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9b0f_row4_col0" class="data row4 col0" >30929.7770</td>
#       <td id="T_d9b0f_row4_col1" class="data row4 col1" >2121784710.5154</td>
#       <td id="T_d9b0f_row4_col2" class="data row4 col2" >46062.8344</td>
#       <td id="T_d9b0f_row4_col3" class="data row4 col3" >0.8471</td>
#       <td id="T_d9b0f_row4_col4" class="data row4 col4" >0.2247</td>
#       <td id="T_d9b0f_row4_col5" class="data row4 col5" >0.1703</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9b0f_row5_col0" class="data row5 col0" >32140.3499</td>
#       <td id="T_d9b0f_row5_col1" class="data row5 col1" >2347669403.3656</td>
#       <td id="T_d9b0f_row5_col2" class="data row5 col2" >48452.7543</td>
#       <td id="T_d9b0f_row5_col3" class="data row5 col3" >0.8060</td>
#       <td id="T_d9b0f_row5_col4" class="data row5 col4" >0.2428</td>
#       <td id="T_d9b0f_row5_col5" class="data row5 col5" >0.1818</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9b0f_row6_col0" class="data row6 col0" >31900.7584</td>
#       <td id="T_d9b0f_row6_col1" class="data row6 col1" >2269309321.7249</td>
#       <td id="T_d9b0f_row6_col2" class="data row6 col2" >47637.2682</td>
#       <td id="T_d9b0f_row6_col3" class="data row6 col3" >0.8274</td>
#       <td id="T_d9b0f_row6_col4" class="data row6 col4" >0.2432</td>
#       <td id="T_d9b0f_row6_col5" class="data row6 col5" >0.1846</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9b0f_row7_col0" class="data row7 col0" >31748.9084</td>
#       <td id="T_d9b0f_row7_col1" class="data row7 col1" >2259941052.3084</td>
#       <td id="T_d9b0f_row7_col2" class="data row7 col2" >47538.8373</td>
#       <td id="T_d9b0f_row7_col3" class="data row7 col3" >0.8293</td>
#       <td id="T_d9b0f_row7_col4" class="data row7 col4" >0.2415</td>
#       <td id="T_d9b0f_row7_col5" class="data row7 col5" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9b0f_row8_col0" class="data row8 col0" >31851.9679</td>
#       <td id="T_d9b0f_row8_col1" class="data row8 col1" >2472984589.7681</td>
#       <td id="T_d9b0f_row8_col2" class="data row8 col2" >49729.1121</td>
#       <td id="T_d9b0f_row8_col3" class="data row8 col3" >0.8084</td>
#       <td id="T_d9b0f_row8_col4" class="data row8 col4" >0.2418</td>
#       <td id="T_d9b0f_row8_col5" class="data row8 col5" >0.1776</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9b0f_row9_col0" class="data row9 col0" >31773.6766</td>
#       <td id="T_d9b0f_row9_col1" class="data row9 col1" >2400687113.7480</td>
#       <td id="T_d9b0f_row9_col2" class="data row9 col2" >48996.8072</td>
#       <td id="T_d9b0f_row9_col3" class="data row9 col3" >0.8130</td>
#       <td id="T_d9b0f_row9_col4" class="data row9 col4" >0.2373</td>
#       <td id="T_d9b0f_row9_col5" class="data row9 col5" >0.1751</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d9b0f_row10_col0" class="data row10 col0" >31665.3298</td>
#       <td id="T_d9b0f_row10_col1" class="data row10 col1" >2297454041.9351</td>
#       <td id="T_d9b0f_row10_col2" class="data row10 col2" >47914.2890</td>
#       <td id="T_d9b0f_row10_col3" class="data row10 col3" >0.8273</td>
#       <td id="T_d9b0f_row10_col4" class="data row10 col4" >0.2333</td>
#       <td id="T_d9b0f_row10_col5" class="data row10 col5" >0.1747</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d9b0f_row11_col0" class="data row11 col0" >369.6052</td>
#       <td id="T_d9b0f_row11_col1" class="data row11 col1" >123711731.6117</td>
#       <td id="T_d9b0f_row11_col2" class="data row11 col2" >1294.1983</td>
#       <td id="T_d9b0f_row11_col3" class="data row11 col3" >0.0149</td>
#       <td id="T_d9b0f_row11_col4" class="data row11 col4" >0.0089</td>
#       <td id="T_d9b0f_row11_col5" class="data row11 col5" >0.0065</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Stack with custom meta-model
lr = create_model('lr')
stacked_custom = stack_models(top3_mae, meta_model=lr)
# Out:
# <style type="text/css">
# #T_b6cea_row10_col0, #T_b6cea_row10_col1, #T_b6cea_row10_col2, #T_b6cea_row10_col3, #T_b6cea_row10_col4, #T_b6cea_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b6cea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6cea_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b6cea_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b6cea_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b6cea_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b6cea_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b6cea_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6cea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6cea_row0_col0" class="data row0 col0" >49499.3263</td>
#       <td id="T_b6cea_row0_col1" class="data row0 col1" >4506434508.5480</td>
#       <td id="T_b6cea_row0_col2" class="data row0 col2" >67129.9822</td>
#       <td id="T_b6cea_row0_col3" class="data row0 col3" >0.6876</td>
#       <td id="T_b6cea_row0_col4" class="data row0 col4" >0.3785</td>
#       <td id="T_b6cea_row0_col5" class="data row0 col5" >0.2860</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6cea_row1_col0" class="data row1 col0" >50087.0365</td>
#       <td id="T_b6cea_row1_col1" class="data row1 col1" >4606880443.1347</td>
#       <td id="T_b6cea_row1_col2" class="data row1 col2" >67874.0042</td>
#       <td id="T_b6cea_row1_col3" class="data row1 col3" >0.6577</td>
#       <td id="T_b6cea_row1_col4" class="data row1 col4" >0.3717</td>
#       <td id="T_b6cea_row1_col5" class="data row1 col5" >0.2800</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6cea_row2_col0" class="data row2 col0" >51054.5333</td>
#       <td id="T_b6cea_row2_col1" class="data row2 col1" >4761455481.8763</td>
#       <td id="T_b6cea_row2_col2" class="data row2 col2" >69003.3005</td>
#       <td id="T_b6cea_row2_col3" class="data row2 col3" >0.6427</td>
#       <td id="T_b6cea_row2_col4" class="data row2 col4" >0.3532</td>
#       <td id="T_b6cea_row2_col5" class="data row2 col5" >0.2878</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6cea_row3_col0" class="data row3 col0" >51507.2264</td>
#       <td id="T_b6cea_row3_col1" class="data row3 col1" >5106069481.4079</td>
#       <td id="T_b6cea_row3_col2" class="data row3 col2" >71456.7665</td>
#       <td id="T_b6cea_row3_col3" class="data row3 col3" >0.6388</td>
#       <td id="T_b6cea_row3_col4" class="data row3 col4" >0.4032</td>
#       <td id="T_b6cea_row3_col5" class="data row3 col5" >0.2948</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6cea_row4_col0" class="data row4 col0" >50112.4279</td>
#       <td id="T_b6cea_row4_col1" class="data row4 col1" >4860155440.2852</td>
#       <td id="T_b6cea_row4_col2" class="data row4 col2" >69714.8151</td>
#       <td id="T_b6cea_row4_col3" class="data row4 col3" >0.6498</td>
#       <td id="T_b6cea_row4_col4" class="data row4 col4" >0.3723</td>
#       <td id="T_b6cea_row4_col5" class="data row4 col5" >0.2871</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6cea_row5_col0" class="data row5 col0" >48621.9962</td>
#       <td id="T_b6cea_row5_col1" class="data row5 col1" >4367867346.5298</td>
#       <td id="T_b6cea_row5_col2" class="data row5 col2" >66089.8430</td>
#       <td id="T_b6cea_row5_col3" class="data row5 col3" >0.6391</td>
#       <td id="T_b6cea_row5_col4" class="data row5 col4" >0.3560</td>
#       <td id="T_b6cea_row5_col5" class="data row5 col5" >0.2830</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6cea_row6_col0" class="data row6 col0" >51188.3408</td>
#       <td id="T_b6cea_row6_col1" class="data row6 col1" >4871208918.3744</td>
#       <td id="T_b6cea_row6_col2" class="data row6 col2" >69794.0464</td>
#       <td id="T_b6cea_row6_col3" class="data row6 col3" >0.6296</td>
#       <td id="T_b6cea_row6_col4" class="data row6 col4" >0.4126</td>
#       <td id="T_b6cea_row6_col5" class="data row6 col5" >0.2998</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6cea_row7_col0" class="data row7 col0" >50310.3244</td>
#       <td id="T_b6cea_row7_col1" class="data row7 col1" >4816859478.7871</td>
#       <td id="T_b6cea_row7_col2" class="data row7 col2" >69403.5985</td>
#       <td id="T_b6cea_row7_col3" class="data row7 col3" >0.6362</td>
#       <td id="T_b6cea_row7_col4" class="data row7 col4" >0.3867</td>
#       <td id="T_b6cea_row7_col5" class="data row7 col5" >0.3007</td>
#     </tr>
#     <tr>
#       <th id="T_b6cea_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_
_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9eaf4_row8_col0" class="data row8 col0" >31851.9679</td>
#       <td id="T_9eaf4_row8_col1" class="data row8 col1" >2472984589.7681</td>
#       <td id="T_9eaf4_row8_col2" class="data row8 col2" >49729.1121</td>
#       <td id="T_9eaf4_row8_col3" class="data row8 col3" >0.8084</td>
#       <td id="T_9eaf4_row8_col4" class="data row8 col4" >0.2418</td>
#       <td id="T_9eaf4_row8_col5" class="data row8 col5" >0.1776</td>
#     </tr>
#     <tr>
#       <th id="T_9eaf4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9eaf4_row9_col0" class="data row9 col0" >31773.6766</td>
#       <td id="T_9eaf4_row9_col1" class="data row9 col1" >2400687113.7480</td>
#       <td id="T_9eaf4_row9_col2" class="data row9 col2" >48996.8072</td>
#       <td id="T_9eaf4_row9_col3" class="data row9 col3" >0.8130</td>
#       <td id="T_9eaf4_row9_col4" class="data row9 col4" >0.2373</td>
#       <td id="T_9eaf4_row9_col5" class="data row9 col5" >0.1751</td>
#     </tr>
#     <tr>
#       <th id="T_9eaf4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9eaf4_row10_col0" class="data row10 col0" >31665.3298</td>
#       <td id="T_9eaf4_row10_col1" class="data row10 col1" >2297454041.9351</td>
#       <td id="T_9eaf4_row10_col2" class="data row10 col2" >47914.2890</td>
#       <td id="T_9eaf4_row10_col3" class="data row10 col3" >0.8273</td>
#       <td id="T_9eaf4_row10_col4" class="data row10 col4" >0.2333</td>
#       <td id="T_9eaf4_row10_col5" class="data row10 col5" >0.1747</td>
#     </tr>
#     <tr>
#       <th id="T_9eaf4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9eaf4_row11_col0" class="data row11 col0" >369.6052</td>
#       <td id="T_9eaf4_row11_col1" class="data row11 col1" >123711731.6117</td>
#       <td id="T_9eaf4_row11_col2" class="data row11 col2" >1294.1983</td>
#       <td id="T_9eaf4_row11_col3" class="data row11 col3" >0.0149</td>
#       <td id="T_9eaf4_row11_col4" class="data row11 col4" >0.0089</td>
#       <td id="T_9eaf4_row11_col5" class="data row11 col5" >0.0065</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Model Interpretation with SHAP

# %%
# Train a tree-based model for interpretation
lgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_14cb0_row10_col0, #T_14cb0_row10_col1, #T_14cb0_row10_col2, #T_14cb0_row10_col3, #T_14cb0_row10_col4, #T_14cb0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_14cb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14cb0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_14cb0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_14cb0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_14cb0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_14cb0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_14cb0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14cb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14cb0_row0_col0" class="data row0 col0" >31916.6222</td>
#       <td id="T_14cb0_row0_col1" class="data row0 col1" >2183766376.9586</td>
#       <td id="T_14cb0_row0_col2" class="data row0 col2" >46730.7862</td>
#       <td id="T_14cb0_row0_col3" class="data row0 col3" >0.8486</td>
#       <td id="T_14cb0_row0_col4" class="data row0 col4" >0.2255</td>
#       <td id="T_14cb0_row0_col5" class="data row0 col5" >0.1734</td>
#     </tr>
#     <tr>
#       <th id="T_14cb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14cb0_row7_col0" class="data row7 col0" >32698.6946</td>
#       <td id="T_14cb0_row7_col1" class="data row7 col1" >2331913339.7254</td>
#       <td id="T_14cb0_row7_col2" class="data row7 col2" >48289.8886</td>
#       <td id="T_14cb0_row7_col3" class="data row7 col3" >0.8239</td>
#       <td id="T_14cb0_row7_col4" class="data row7 col4" >0.2465</td>
#       <td id="T_14cb0_row7_col5" class="data row7 col5" >0.1895</td>
#     </tr>
#     <tr>
#       <th id="T_14cb0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14cb0_row8_col0" class="data row8 col0" >32531.0013</td>
#       <td id="T_14cb0_row8_col1" class="data row8 col1" >2516408893.3986</td>
#       <td id="T_14cb0_row8_col2" class="data row8 col2" >50163.8206</td>
#       <td id="T_14cb0_row8_col3" class="data row8 col3" >0.8050</td>
#       <td id="T_14cb0_row8_col4" class="data row8 col4" >0.2450</td>
#       <td id="T_14cb0_row8_col5" class="data row8 col5" >0.1821</td>
#     </tr>
#     <tr>
#       <th id="T_14cb0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14cb0_row9_col0" class="data row9 col0" >32593.6964</td>
#       <td id="T_14cb0_row9_col1" class="data row9 col1" >2468869367.5901</td>
#       <td id="T_14cb0_row9_col2" class="data row9 col2" >49687.7185</td>
#       <td id="T_14cb0_row9_col3" class="data row9 col3" >0.8076</td>
#       <td id="T_14cb0_row9_col4" class="data row9 col4" >0.2422</td>
#       <td id="T_14cb0_row9_col5" class="data row9 col5" >0.1812</td>
#     </tr>
#     <tr>
#       <th id="T_14cb0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_14cb0_row10_col0" class="data row10 col0" >32446.5243</td>
#       <td id="T_14cb0_row10_col1" class="data row10 col1" >2352506625.5720</td>
#       <td id="T_14cb0_row10_col2" class="data row10 col2" >48484.5478</td>
#       <td id="T_14cb0_row10_col3" class="data row10 col3" >0.8231</td>
#       <td id="T_14cb0_row10_col4" class="data row10 col4" >0.2376</td>
#       <td id="T_14cb0_row10_col5" class="data row10 col5" >0.1806</td>
#     </tr>
#     <tr>
#       <th id="T_14cb0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_14cb0_row11_col0" class="data row11 col0" >397.0405</td>
#       <td id="T_14cb0_row11_col1" class="data row11 col1" >127982653.3740</td>
#       <td id="T_14cb0_row11_col2" class="data row11 col2" >1324.8590</td>
#       <td id="T_14cb0_row11_col3" class="data row11 col3" >0.0153</td>
#       <td id="T_14cb0_row11_col4" class="data row11 col4" >0.0089</td>
#       <td id="T_14cb0_row11_col5" class="data row11 col5" >0.0065</td>
#     </tr>
#   </tbody>
# </table>

# %%
# SHAP summary plot
interpret_model(lgbm, plot='summary')

# %%
# SHAP reason plot for a specific prediction
interpret_model(lgbm, plot='reason', observation=0)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i844YFH77NKZBQFJ2HE5K'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 207524.77171889783, "outValue": 198882.8141872336, "link": "identity", "featureNames": ["longitude", "latitude", "housing_median_age", "total_rooms", "total_bedrooms", "population", "households", "median_income", "ocean_proximity_INLAND", "ocean_proximity_<1H OCEAN", "ocean_proximity_NEAR BAY", "ocean_proximity_NEAR OCEAN", "ocean_proximity_ISLAND"], "features": {"0": {"effect": 49919.216070176786, "value": -122.63999938964844}, "1": {"effect": -49117.676243968526, "value": 38.2400016784668}, "2": {"effect": 4247.608199655069, "value": 40.0}, "3": {"effect": -1927.2682363279416, "value": 1974.0}, "4": {"effect": -5817.210463150932, "value": 410.0}, "5": {"effect": -4702.589400646292, "value": 1039.0}, "6": {"effect": -1524.0767214709726, "value": 398.0}, "7": {"effect": -18836.22955808846, "value": 3.7916998863220215}, "8": {"effect": 25720.670748744793, "value": 0.0}, "9": {"effect": -1504.4349225474157, "value": 1.0}, "10": {"effect": -3853.408436082559, "value": 0.0}, "11": {"effect": -1246.5585679577866, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i844YFH77NKZBQFJ2HE5K')
#   );
# </script>

# %%
# SHAP correlation plot
interpret_model(lgbm, plot='correlation')

# %% [markdown]
# ## Leaderboard & AutoML

# %%
# Get leaderboard of all trained models
lb = get_leaderboard()
lb
# Out:
#                             Model Name  \
# Index
# 0                    Linear Regression
# 1                     Lasso Regression
# 2                     Ridge Regression
# 3                          Elastic Net
# 4               Least Angle Regression
# 5         Lasso Least Angle Regression
# 6          Orthogonal Matching Pursuit
# 7                       Bayesian Ridge
# 8         Passive Aggressive Regressor
# 9                      Huber Regressor
# 10               K Neighbors Regressor
# 11             Decision Tree Regressor
# 12             Random Forest Regressor
# 13               Extra Trees Regressor
# 14                  AdaBoost Regressor
# 15         Gradient Boosting Regressor
# 16     Light Gradient Boosting Machine
# 17                     Dummy Regressor
# 18             Decision Tree Regressor
# 19             Random Forest Regressor
# 20               Extra Trees Regressor
# 21         Gradient Boosting Regressor
# 22     Light Gradient Boosting Machine
# 23                  AdaBoost Regressor
# 24                   Linear Regression
# 25                    Lasso Regression
# 26                    Ridge Regression
# 27                         Elastic Net
# 28              Least Angle Regression
# 29        Lasso Least Angle Regression
# 30         Orthogonal Matching Pursuit
# 31                      Bayesian Ridge
# 32        Passive Aggressive Regressor
# 33                     Huber Regressor
# 34               K Neighbors Regressor
# 35             Decision Tree Regressor
# 36             Random Forest Regressor
# 37               Extra Trees Regressor
# 38                  AdaBoost Regressor
# 39         Gradient Boosting Regressor
# 40     Light Gradient Boosting Machine
# 41                     Dummy Regressor
# 42             Decision Tree Regressor
# 43             Decision Tree Regressor
# 44             Decision Tree Regressor
# 45             Decision Tree Regressor
# 46             Decision Tree Regressor
# 47             Decision Tree Regressor
# 48             Decision Tree Regressor
# 49                    Voting Regressor
# 50                  Stacking Regressor
# 51                   Linear Regression
# 52                  Stacking Regressor
# 53     Light Gradient Boosting Machine
#
#                                                    Model          MAE  \
# Index
# 0      (TransformerWrapper(include=['longitude', 'lat...   50154.1376
# 1      (TransformerWrapper(include=['longitude', 'lat...   50154.5348
# 2      (TransformerWrapper(include=['longitude', 'lat...   50155.4032
# 3      (TransformerWrapper(include=['longitude', 'lat...   52987.3000
# 4      (TransformerWrapper(include=['longitude', 'lat...   50318.6460
# 5      (TransformerWrapper(include=['longitude', 'lat...   50154.5079
# 6      (TransformerWrapper(include=['longitude', 'lat...   90017.7920
# 7      (TransformerWrapper(include=['longitude', 'lat...   50167.2546
# 8      (TransformerWrapper(include=['longitude', 'lat...  193020.4212
# 9      (TransformerWrapper(include=['longitude', 'lat...   54495.5520
# 10     (TransformerWrapper(include=['longitude', 'lat...   76416.2766
# 11     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 12     (TransformerWrapper(include=['longitude', 'lat...   32601.1401
# 13     (TransformerWrapper(include=['longitude', 'lat...   35279.0180
# 14     (TransformerWrapper(include=['longitude', 'lat...   76376.0145
# 15     (TransformerWrapper(include=['longitude', 'lat...   39009.2448
# 16     (TransformerWrapper(include=['longitude', 'lat...   32446.5243
# 17     (TransformerWrapper(include=['longitude', 'lat...   91282.2086
# 18     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 19     (TransformerWrapper(include=['longitude', 'lat...   32601.1401
# 20     (TransformerWrapper(include=['longitude', 'lat...   35279.0180
# 21     (TransformerWrapper(include=['longitude', 'lat...   39009.2448
# 22     (TransformerWrapper(include=['longitude', 'lat...   32446.5243
# 23     (TransformerWrapper(include=['longitude', 'lat...   76376.0145
# 24     (TransformerWrapper(include=['longitude', 'lat...   50154.1376
# 25     (TransformerWrapper(include=['longitude', 'lat...   50154.5348
# 26     (TransformerWrapper(include=['longitude', 'lat...   50155.4032
# 27     (TransformerWrapper(include=['longitude', 'lat...   52987.3000
# 28     (TransformerWrapper(include=['longitude', 'lat...   50318.6460
# 29     (TransformerWrapper(include=['longitude', 'lat...   50154.5079
# 30     (TransformerWrapper(include=['longitude', 'lat...   90017.7920
# 31     (TransformerWrapper(include=['longitude', 'lat...   50167.2546
# 32     (TransformerWrapper(include=['longitude', 'lat...  193020.4212
# 33     (TransformerWrapper(include=['longitude', 'lat...   54495.5520
# 34     (TransformerWrapper(include=['longitude', 'lat...   76416.2766
# 35     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 36     (TransformerWrapper(include=['longitude', 'lat...   32601.1401
# 37     (TransformerWrapper(include=['longitude', 'lat...   35279.0180
# 38     (TransformerWrapper(include=['longitude', 'lat...   76376.0145
# 39     (TransformerWrapper(include=['longitude', 'lat...   39009.2448
# 40     (TransformerWrapper(include=['longitude', 'lat...   32446.5243
# 41     (TransformerWrapper(include=['longitude', 'lat...   91282.2086
# 42     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 43     (TransformerWrapper(include=['longitude', 'lat...   40657.0996
# 44     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 45     (TransformerWrapper(include=['longitude', 'lat...   40680.4468
# 46     (TransformerWrapper(include=['longitude', 'lat...   44638.4876
# 47     (TransformerWrapper(include=['longitude', 'lat...   34360.9888
# 48     (TransformerWrapper(include=['longitude', 'lat...   33847.9625
# 49     (TransformerWrapper(include=['longitude', 'lat...   32275.0046
# 50     (TransformerWrapper(include=['longitude', 'lat...   31665.3298
# 51     (TransformerWrapper(include=['longitude', 'lat...   50154.1376
# 52     (TransformerWrapper(include=['longitude', 'lat...   31665.3298
# 53     (TransformerWrapper(include=['longitude', 'lat...   32446.5243
#
#                 MSE         RMSE       R2   RMSLE    MAPE
# Index
# 0      4.757779e+09   68960.1376   0.6429  0.3811  0.2885
# 1      4.757788e+09   68960.2055   0.6429  0.3811  0.2885
# 2      4.757763e+09   68960.0498   0.6429  0.3810  0.2885
# 3      5.140503e+09   71685.9834   0.6143  0.3709  0.3198
# 50     2.297454e+09   47914.2890   0.8273  0.2333  0.1747
# 51     4.757779e+09   68960.1376   0.6429  0.3811  0.2885
# 52     2.297454e+09   47914.2890   0.8273  0.2333  0.1747
# 53     2.352507e+09   48484.5478   0.8231  0.2376  0.1806

# %%
# Find best model by specific metric
best_by_mae = lb.sort_values(by='MAE', ascending=True).iloc[0]

print(f"Best model by MAE: {best_by_mae['Model']}")
print(f"MAE: ${best_by_mae['MAE']:,.2f}")
print(f"RMSE: ${best_by_mae['RMSE']:,.2f}")
print(f"R²: {best_by_mae['R2']:.4f}")
# Out:
# Best model by MAE: Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['longitude', 'latitude',
#                                              'housing_median_age',
#                                              'total_rooms', 'total_bedrooms',
#                                              'population', 'households',
#                                              'median_income'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['ocean_proximity'],
#                                     transformer=SimpleImputer(strategy='mo...
#                                                               use_cat_names=True))),
#                 ['trained_model',
#                  StackingRegressor(cv=5,
#                                    estimators=[('Light Gradient Boosting '
#                                                 'Machine',
#                                                 LGBMRegressor(n_jobs=-1,
#                                                               random_state=123)),
#                                                ('Random Forest Regressor',
#                                                 RandomForestRegressor(n_jobs=-1,
#                                                                       random_state=123)),
#                                                ('Extra Trees Regressor',
#                                                 ExtraTreesRegressor(n_jobs=-1,
#                                                                     random_state=123))],
#                                    final_estimator=LinearRegression(n_jobs=-1),
#                                    n_jobs=-1)]])
# MAE: $31,665.33
# RMSE: $47,914.29
# R²: 0.8273

# %%
# AutoML - automatically select and return best model
best_model = automl(optimize='MAE')

print(f"\nAutoML selected: {type(best_model).__name__}")
# Out:
# AutoML selected: StackingRegressor

# %% [markdown]
# ## Advanced Setup Options

# %%
# Access experiment configuration
config = get_config()

print("Configuration type:", type(config))
print("Available config keys (first 15):")
config_list = list(config) if isinstance(config, set) else list(config.keys())
print(config_list[:15])
# Out:
# Configuration type: <class 'set'>
# Available config keys (first 15):
# ['X_test', 'logging_param', 'y_test_transformed', 'exp_id', 'fold_shuffle_param', 'gpu_param', 'fold_groups_param', 'seed', 'exp_name_log', 'X_transformed', 'y', 'test_transformed', 'dataset', 'y_test', 'variable_and_property_keys']

# %%
# Access specific configuration elements
X_train = get_config('X_train')
X_test = get_config('X_test')
y_train = get_config('y_train')
y_test = get_config('y_test')

print(f"Training set: {X_train.shape}")
print(f"Test set: {X_test.shape}")
print(f"Target (train): {y_train.shape}")
print(f"Target (test): {y_test.shape}")
# Out:
# Training set: (14447, 9)
# Test set: (6193, 9)
# Target (train): (14447,)
# Target (test): (6193,)

# %%
# SKIPPED: Advanced setup example (optional)
# # Setup with advanced preprocessing
# s2 = setup(
#     data, 
#     target='median_house_value',
#     session_id=456,
#     normalize=True,              # Normalize features
#     normalize_method='minmax',   # Use Min-Max normalization
#     transformation=True,          # Transform features
#     transformation_method='yeo-johnson',  # Yeo-Johnson transformation
#     feature_selection=True,      # Perform feature selection
#     remove_multicollinearity=True,  # Remove multicollinear features
#     multicollinearity_threshold=0.9,
#     train_size=0.8               # Use 80% for training
# )

# %%
# SKIPPED: Column names may change after transformation
# The transformed data may have different column names
# Use get_config('X_train_transformed') to see actual transformed data

# Show first few rows of transformed data instead
X_transformed = get_config('X_train_transformed')
print("Transformed data shape:", X_transformed.shape)
print("\nFirst few rows of transformed data:")
print(X_transformed.head())
# Out:
# Transformed data shape: (14447, 13)
#
# First few rows of transformed data:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12271 -117.040001  34.000000                21.0       4624.0           852.0
# 19605 -121.029999  37.549999                32.0        946.0           198.0
# 10600 -117.800003  33.680000                 8.0       2032.0           349.0
# 45    -122.260002  37.830002                52.0       1656.0           420.0
# 2889  -118.989998  35.389999                52.0       2805.0           573.0
#
#        population  households  median_income  ocean_proximity_INLAND  \
# 12271      2174.0       812.0         3.5255                     1.0
# 19605       624.0       173.0         1.9728                     1.0
# 10600       862.0       340.0         6.9133                     0.0
# 45          718.0       382.0         2.6768                     0.0
# 2889       1325.0       522.0         2.5083                     1.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_NEAR BAY  \
# 12271                        0.0                       0.0
# 19605                        0.0                       0.0
# 10600                        1.0                       0.0
# 45                           0.0                       1.0
# 2889                         0.0                       0.0
#
#        ocean_proximity_NEAR OCEAN  ocean_proximity_ISLAND
# 12271                         0.0                     0.0
# 19605                         0.0                     0.0
# 10600                         0.0                     0.0
# 45                            0.0                     0.0
# 2889                          0.0                     0.0

# %% [markdown]
# ## Deployment Tools

# %%
# Finalize model (retrain on full dataset including holdout)
final_model = finalize_model(best)

print(f"✅ Final model trained on full dataset: {type(final_model).__name__}")
# Out:
# ✅ Final model trained on full dataset: Pipeline

# %%
# SKIPPED: Optional deployment feature
# # Create FastAPI application
# create_api(final_model, api_name='insurance_api')
# 
# print("\n✅ API files created:")
# print("  - insurance_api.py (FastAPI application)")
# print("\nTo run the API:")
# print("  python insurance_api.py")

# %%
# SKIPPED: Optional deployment feature
# # Create Docker configuration
# create_docker('insurance_api')
# 
# print("\n✅ Docker files created:")
# print("  - Dockerfile")
# print("  - requirements.txt")
# print("\nTo build and run:")
# print("  docker build -t insurance-api .")
# print("  docker run -p 8000:8000 insurance-api")

# %%
# SKIPPED: Optional Gradio app feature
# # Create Gradio app for interactive predictions
# create_app(final_model)
# 
# # This will launch an interactive web interface

# %%
# SKIPPED: Optional dashboard feature
# # Create dashboard
# dashboard(best, display_format='inline')
# 
# # This creates an interactive dashboard in the notebook

# %%
# SKIPPED: Optional model conversion feature
# # Convert model to different programming languages
# java_code = convert_model(dt, language='java')
# 
# print("Java code (first 500 characters):")
# print(java_code[:500])
# print("\n... (truncated)")

# %% [markdown]
# ## Experiment Persistence

# %%
# Save entire experiment (all models, transformations, config)
save_experiment('insurance_experiment')

print("✅ Experiment saved as 'insurance_experiment.pkl'")
# Out:
# ✅ Experiment saved as 'insurance_experiment.pkl'

# %%
# Load experiment
loaded_exp = load_experiment('insurance_experiment', data=data)

print("✅ Experiment loaded successfully!")
print("\nYou can now use all models and continue where you left off.")
# Out:
# <style type="text/css">
# #T_a2696_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a2696">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2696_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a2696_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2696_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2696_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a2696_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2696_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a2696_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2696_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a2696_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a2696_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a2696_row3_col1" class="data row3 col1" >(20640, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a2696_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a2696_row4_col1" class="data row4 col1" >(20640, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a2696_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a2696_row5_col1" class="data row5 col1" >(14447, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a2696_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a2696_row6_col1" class="data row6 col1" >(6193, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a2696_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a2696_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a2696_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_a2696_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a2696_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_a2696_row9_col1" class="data row9 col1" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a2696_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_a2696_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a2696_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_a2696_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a2696_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_a2696_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a2696_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_a2696_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a2696_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_a2696_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a2696_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_a2696_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a2696_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_a2696_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a2696_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_a2696_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a2696_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_a2696_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a2696_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_a2696_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a2696_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_a2696_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a2696_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_a2696_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a2696_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a2696_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_a2696_row22_col1" class="data row22 col1" >830e</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Experiment loaded successfully!
#
# You can now use all models and continue where you left off.

# %% [markdown]
# ---
#
# # 🎉 Congratulations!
#
# You've completed the PyCaret Regression tutorial!
#
# ## What You Learned
#
# ✅ **Environment Setup** - Configuring PyCaret with preprocessing pipelines
# ✅ **AutoML** - Automatically comparing 25+ regression models
# ✅ **Model Analysis** - Visualizing performance with various plots
# ✅ **Hyperparameter Tuning** - Optimizing models with multiple strategies
# ✅ **Ensemble Methods** - Bagging, boosting, blending, and stacking
# ✅ **Model Interpretation** - Understanding predictions with SHAP
# ✅ **Deployment** - Creating APIs, dashboards, and Docker containers
# ✅ **Persistence** - Saving and loading models and experiments
#
# ## Key Takeaways
#
# 1. **Low-Code ML**: PyCaret reduces hundreds of lines to just a few
# 2. **Automation**: Compare models, tune parameters, and ensemble automatically
# 3. **Production-Ready**: Built-in tools for deployment and monitoring
# 4. **Flexibility**: Both functional and OOP APIs available
# 5. **Comprehensive**: Covers entire ML lifecycle from data to deployment
#
# ## Next Steps
#
# 1. **Try your own data** - Apply PyCaret to your projects
# 2. **Explore other modules** - Classification, Clustering, Anomaly Detection, Time Series
# 3. **Deploy a model** - Use the API and Docker files created
# 4. **Join the community** - Contribute and learn from others
#
# ## Resources
#
# - **Documentation:** https://pycaret.readthedocs.io
# - **GitHub:** https://github.com/pycaret/pycaret
# - **Tutorials:** https://pycaret.gitbook.io
# - **API Reference:** https://pycaret.readthedocs.io/en/latest/api/regression.html
# - **Community:** https://github.com/pycaret/pycaret/discussions
#
# ---
#
# **Course:** CMPE-255 Data Mining
# **Institution:** San José State University
# **Instructor:** Dr. Carlos Rojas
#
# Happy Machine Learning! 🚀
